# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import pandas as pd
from bs4 import BeautifulSoup
import itertools
import more_itertools
import numpy as np
import pickle

# %%
df=pd.read_csv('imdb.csv')

# %%
train = df[df['testOtrain'] == 'train']
test = df[df['testOtrain'] == 'test']

# %%
max_sent_len = 20
max_seq_len = 200

# %%
def clean_str(string, max_seq_len):
    """
    adapted from https://github.com/yoonkim/CNN_sentence/blob/master/process_data.py
    """
    string = BeautifulSoup(string, "lxml").text
    string = re.sub(r"[^A-Za-z0-9(),!?\"\`]", " ", string)
    string = re.sub(r"\"s", " \"s", string)
    string = re.sub(r"\"ve", " \"ve", string)
    string = re.sub(r"n\"t", " n\"t", string)
    string = re.sub(r"\"re", " \"re", string)
    string = re.sub(r"\"d", " \"d", string)
    string = re.sub(r"\"ll", " \"ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", " \( ", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)
    s =string.strip().lower().split(" ")
    if len(s) > max_seq_len:
        return s[0:max_seq_len] 
    return s

# %%
def create3DList(df, max_sent_len,max_seq_len):
    x=[]
    for docs in df["content"].as_matrix():
        x1=[]
        idx = 0
        for seq in "|||".join(re.split("[.?!]", docs)).split("|||"):
            x1.append(clean_str(seq,max_seq_len))
            if(idx>max_sent_len):
                break
            idx= idx+1
        x.append(x1)
    return x

# %%
#divides review in sentences and sentences into word creating a 3DList

x_train = create3DList(train, max_sent_len,max_seq_len)
x_test = create3DList(test, max_sent_len,max_seq_len)
print("x_train: {}".format(len(x_train)))
print("x_test: {}".format(len(x_test)))
# Out:
# /usr/lib/python3/dist-packages/bs4/__init__.py:198: UserWarning: "b'/'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   '"%s" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.' % markup)
# /usr/lib/python3/dist-packages/bs4/__init__.py:207: UserWarning: "b'http://video'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# x_train: 25000
# x_test: 25000

# %%
def index(data):
    def apply_index(data):
        indexed = [[[unqVoc_LookUp[char] for char in seq] for seq in doc] for doc in data]
        return indexed
    # end

    x_train, x_test = data

    unqVoc = set(list(more_itertools.collapse(x_train[:] + x_test[:])))
    unqVoc_LookUp = {k: v+1 for v, k in enumerate(unqVoc)}
    vocab_size = len(list(unqVoc_LookUp))

    # save lookup table
    pickle._dump(unqVoc_LookUp, open("unqVoc_Lookup.p","wb"))

    x_train = apply_index(data=x_train)
    x_test = apply_index(data=x_test)

    return [x_train, x_test,vocab_size,unqVoc_LookUp]

# %%
x_train, x_test,vocab_size,lookup = index(data=[x_train[:], x_test[:]])

# %%
y_train = train["label"].tolist()
y_test = test["label"].tolist()

# %%
def attention_mul(rnn_outputs, att_weights):
    attn_vectors = None
    for i in range(rnn_outputs.size(0)):
        h_i = rnn_outputs[i]
        a_i = att_weights[i]
        h_i = a_i * h_i
        h_i = h_i.unsqueeze(0)
        if(attn_vectors is None):
            attn_vectors = h_i
        else:
            attn_vectors = torch.cat((attn_vectors,h_i),0)
    return torch.sum(attn_vectors, 0).unsqueeze(0)

# %%
class WordRNN(nn.Module):
    def __init__(self, vocab_size,embedsize, batch_size, hid_size):
        super(WordRNN, self).__init__()
        self.batch_size = batch_size
        self.embedsize = embedsize
        self.hid_size = hid_size
        ## Word Encoder
        self.embed = nn.Embedding(vocab_size, embedsize)
        self.wordRNN = nn.GRU(embedsize, hid_size, bidirectional=True)
        ## Word Attention
        self.wordattn = nn.Linear(2*hid_size, 2*hid_size)
        self.attn_combine = nn.Linear(2*hid_size, 2*hid_size,bias=False)
    def forward(self,inp, hid_state):
        try:
            emb_out  = self.embed(inp)
        
            out_state, hid_state = self.wordRNN(emb_out, hid_state)
#         print(out_state.shape)
#         print(hid_state.view(1,self.batch_size,2*self.hid_size).shape)
            word_annotation = self.wordattn(out_state)
            attn = F.softmax(self.attn_combine(word_annotation),dim=1)
#         print(attn.shape)
            sent = attention_mul(out_state,attn)
            return sent, hid_state
        except:
            print(inp)
            print(hid_state)
    def init_hidden(self):
            return Variable(torch.zeros(2, self.batch_size, self.hid_size))

# %%
class SentenceRNN(nn.Module):
    def __init__(self,embedsize, batch_size, hid_size,c):
        super(SentenceRNN, self).__init__()
        self.batch_size = batch_size
        self.embedsize = embedsize
        self.hid_size = hid_size
        self.cls = c
        ## Sentence Encoder
        self.sentRNN = nn.GRU(embedsize, hid_size, bidirectional=True)
        ## Sentence Attention
        self.sentattn = nn.Linear(2*hid_size, 2*hid_size)
        self.attn_combine = nn.Linear(2*hid_size, 2*hid_size,bias=False)
        self.doc_linear = nn.Linear(2*hid_size, c)
    
    def forward(self,inp, hid_state):        
        out_state, hid_state = self.sentRNN(inp, hid_state)
#         print(out_state.shape)
#         print(hid_state.view(1,self.batch_size,2*self.hid_size).shape)
        sent_annotation = self.sentattn(out_state)
        attn = F.softmax(self.attn_combine(sent_annotation),dim=1)
#         print(attn.shape)
        doc = attention_mul(out_state,attn)
        d = self.doc_linear(doc)
#         print(d)
        cls = F.softmax(d.view(self.cls,-1),dim=0)
        return cls, hid_state
    
    def init_hidden(self):
            return Variable(torch.zeros(2, self.batch_size, self.hid_size))

# %%
y_train_one =  [torch.LongTensor([int(label)]) for label in y_train]

# %%
max_seq_len = max([len(seq) for seq in itertools.chain.from_iterable(x_train + x_test)])
max_sent_len = max([len(sent) for sent in (x_train+x_test)])

# %%
max_seq_len
# Out:
# 200

# %%
max_sent_len
# Out:
# 22

# %%
X1 = [sub_list + [[0]] * (max_sent_len - len(sub_list)) for sub_list in x_train]

# %%
batch_size = 1

# %%
def train_data(batch_size, review, targets, word_attn_model, sent_attn_model, word_optimizer, sent_optimizer, criterion):

#     max_sents, batch_size, max_tokens = mini_batch.size()
    state_word = word_attn_model.init_hidden()
    state_sent = sent_attn_model.init_hidden()
    word_optimizer.zero_grad()
    sent_optimizer.zero_grad()
#     print(review)
    s = None
    for i in range(len(review[0])):
        r = None
        for j in range(len(review)):
            if(r is None):
                r = [review[j][i]]
            else:
                r.append(review[j][i])
        r1 = np.asarray([sub_list + [0] * (max_seq_len - len(sub_list)) for sub_list in r])
#         print(r1.shape)
        _s, state_word = word_attn_model(torch.tensor(r1).view(-1,batch_size), state_word)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)            
    y_pred, state_sent = sent_attn_model(s, state_sent)
#     print(y_pred)
#     print(targets)
    
    loss = criterion(y_pred.view(-1,2), torch.tensor(targets)) 
    max_index = y_pred.view(-1,2).max(dim = 1)[1]
    correct = (max_index == torch.tensor(targets)).sum()
    acc = correct/batch_size
    loss.backward()
    
    word_optimizer.step()
    sent_optimizer.step()
    
    return loss.data[0],acc

# %%
word_attn = WordRNN(vocab_size,100,batch_size,100)

# %%
sent_attn = SentenceRNN(200,batch_size,200,2)

# %%
learning_rate = 1e-3
momentum = 0.5
word_optmizer = torch.optim.SGD(word_attn.parameters(), lr=learning_rate, momentum= momentum)
sent_optimizer = torch.optim.SGD(sent_attn.parameters(), lr=learning_rate, momentum= momentum)

criterion = nn.NLLLoss()

# %%
import time
import math

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
def gen_batch(x,y,batch_size,max_sent_len):
    k = random.sample(range(len(x)-1),batch_size)
    x_batch=[]
    y_batch=[]
#     print(x_batch)
    for t in k:
        x_batch.append(x[t])
        y_batch.append(y[t])
    x_batch = [sub_list + [[0]] * (max_sent_len - len(sub_list)) for sub_list in x_batch]
    return [x_batch,y_batch]

# %%
def train_early_stopping(batch_size, X_train, y_train, word_attn_model, sent_attn_model, 
                         word_attn_optimiser, sent_attn_optimiser, loss_criterion, num_epoch,max_sent_len,
                         print_val_loss_every = 1000, print_loss_every = 50):
    start = time.time()
    loss_full = []
    loss_epoch = []
    acc_epoch = []
    acc_full = []
    epoch_counter = 0
    train_length = len(x_train)
    for i in range(1, num_epoch + 1):
        try:
            loss_epoch = []
            acc_epoch = []
            for j in range(int(train_length/batch_size)):
                x,y = gen_batch(X_train,y_train,batch_size,max_sent_len)
                loss,acc = train_data(batch_size, x, y, word_attn_model, sent_attn_model, word_attn_optimiser, sent_attn_optimiser, loss_criterion)
                loss_full.append(loss)
                loss_epoch.append(loss)
                acc_full.append(acc)
                acc_epoch.append(acc)
                if j % print_loss_every == 0:
                    print ('Loss at %d paragraphs, %d epoch,(%s) is %f' %(j, i, timeSince(start), np.mean(loss_epoch)))
                    print ('Accuracy at %d paragraphs, %d epoch,(%s) is %f' %(j, i, timeSince(start), np.mean(acc_epoch)))
            torch.save(word_attn_model.state_dict(), 'word_attn_model' + str(i+1)+'.pth')
            torch.save(sent_attn_model.state_dict(), 'sent_attn_model' + str(i+1)+'.pth')
        except StopIteration:
            epoch_counter += 1
            print ('Reached %d epocs' % epoch_counter)
            print ('i %d' % i)
            g = gen_minibatch(X_train, y_train, mini_batch_size)
            loss_epoch = []
            accuracy_epoch = []
    return loss_full, state_word, state_sent

# %%
 

loss_full, state_word_train, state_sent_train = train_early_stopping(batch_size, x_train, y_train_one, word_attn, sent_attn, word_optmizer, sent_optimizer, 
                            criterion, 10,max_sent_len)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:37: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Loss at 0 paragraphs, 1 epoch,(0m 3s) is -0.928255
# Accuracy at 0 paragraphs, 1 epoch,(0m 3s) is 1.000000
# Loss at 50 paragraphs, 1 epoch,(3m 9s) is -0.469181
# Accuracy at 50 paragraphs, 1 epoch,(3m 9s) is 0.470588
# Loss at 100 paragraphs, 1 epoch,(6m 14s) is -0.484438
# Accuracy at 100 paragraphs, 1 epoch,(6m 14s) is 0.485149
# Loss at 150 paragraphs, 1 epoch,(9m 20s) is -0.535949
# Accuracy at 150 paragraphs, 1 epoch,(9m 20s) is 0.536424
# Loss at 200 paragraphs, 1 epoch,(12m 24s) is -0.527006
# Accuracy at 200 paragraphs, 1 epoch,(12m 24s) is 0.527363
# Loss at 250 paragraphs, 1 epoch,(15m 29s) is -0.493738
# Accuracy at 250 paragraphs, 1 epoch,(15m 29s) is 0.494024
# Loss at 300 paragraphs, 1 epoch,(18m 33s) is -0.491456
# Accuracy at 300 paragraphs, 1 epoch,(18m 33s) is 0.491694
# Loss at 350 paragraphs, 1 epoch,(21m 37s) is -0.489824
# Accuracy at 350 paragraphs, 1 epoch,(21m 37s) is 0.490028
# Loss at 400 paragraphs, 1 epoch,(24m 42s) is -0.518524
# Accuracy at 400 paragraphs, 1 epoch,(24m 42s) is 0.518703
# Loss at 450 paragraphs, 1 epoch,(27m 46s) is -0.516471
# Accuracy at 450 paragraphs, 1 epoch,(27m 46s) is 0.516630
# Loss at 500 paragraphs, 1 epoch,(30m 50s) is -0.514827
# Accuracy at 500 paragraphs, 1 epoch,(30m 50s) is 0.514970
# Loss at 550 paragraphs, 1 epoch,(33m 55s) is -0.504407
# Accuracy at 550 paragraphs, 1 epoch,(33m 55s) is 0.504537
# Loss at 600 paragraphs, 1 epoch,(36m 59s) is -0.507368
# Accuracy at 600 paragraphs, 1 epoch,(36m 59s) is 0.507488
# Loss at 650 paragraphs, 1 epoch,(40m 4s) is -0.505266
# Accuracy at 650 paragraphs, 1 epoch,(40m 4s) is 0.505376
# Loss at 700 paragraphs, 1 epoch,(43m 8s) is -0.506317
# Accuracy at 700 paragraphs, 1 epoch,(43m 8s) is 0.506419
# Loss at 750 paragraphs, 1 epoch,(46m 13s) is -0.509891
# Accuracy at 750 paragraphs, 1 epoch,(46m 13s) is 0.509987
# Loss at 800 paragraphs, 1 epoch,(49m 17s) is -0.503032
# Accuracy at 800 paragraphs, 1 epoch,(49m 17s) is 0.503121
# Loss at 850 paragraphs, 1 epoch,(52m 22s) is -0.504028
# Accuracy at 850 paragraphs, 1 epoch,(52m 22s) is 0.504113
# Loss at 900 paragraphs, 1 epoch,(55m 26s) is -0.503805
# Accuracy at 900 paragraphs, 1 epoch,(55m 26s) is 0.503885
# Loss at 950 paragraphs, 1 epoch,(58m 31s) is -0.500450
# Accuracy at 950 paragraphs, 1 epoch,(58m 31s) is 0.500526
# Loss at 1000 paragraphs, 1 epoch,(61m 35s) is -0.497431
# Accuracy at 1000 paragraphs, 1 epoch,(61m 35s) is 0.497502
# Loss at 1050 paragraphs, 1 epoch,(64m 40s) is -0.497553
# Accuracy at 1050 paragraphs, 1 epoch,(64m 40s) is 0.497621
# Loss at 1100 paragraphs, 1 epoch,(67m 44s) is -0.503114
# Accuracy at 1100 paragraphs, 1 epoch,(67m 44s) is 0.503179
# Loss at 1150 paragraphs, 1 epoch,(70m 49s) is -0.500372
# Accuracy at 1150 paragraphs, 1 epoch,(70m 49s) is 0.500434
# Loss at 1200 paragraphs, 1 epoch,(73m 54s) is -0.502022
# Accuracy at 1200 paragraphs, 1 epoch,(73m 54s) is 0.502082
# Loss at 1250 paragraphs, 1 epoch,(76m 58s) is -0.501142
# Accuracy at 1250 paragraphs, 1 epoch,(76m 58s) is 0.501199
# Loss at 1300 paragraphs, 1 epoch,(80m 3s) is -0.503404
# Accuracy at 1300 paragraphs, 1 epoch,(80m 3s) is 0.503459
# Loss at 1350 paragraphs, 1 epoch,(83m 7s) is -0.504018
# Accuracy at 1350 paragraphs, 1 epoch,(83m 7s) is 0.504071
# Loss at 1400 paragraphs, 1 epoch,(86m 12s) is -0.502447
# Accuracy at 1400 paragraphs, 1 epoch,(86m 12s) is 0.502498
# Loss at 1450 paragraphs, 1 epoch,(89m 16s) is -0.501673
# Accuracy at 1450 paragraphs, 1 epoch,(89m 16s) is 0.501723
# Loss at 1500 paragraphs, 1 epoch,(92m 21s) is -0.504949
# Accuracy at 1500 paragraphs, 1 epoch,(92m 21s) is 0.504997
# Loss at 1550 paragraphs, 1 epoch,(95m 25s) is -0.506724
# Accuracy at 1550 paragraphs, 1 epoch,(95m 25s) is 0.506770
# Loss at 1600 paragraphs, 1 epoch,(98m 30s) is -0.506514
# Accuracy at 1600 paragraphs, 1 epoch,(98m 30s) is 0.506558
# Loss at 1650 paragraphs, 1 epoch,(101m 34s) is -0.506316
# Accuracy at 1650 paragraphs, 1 epoch,(101m 35s) is 0.506360
# Loss at 1700 paragraphs, 1 epoch,(104m 39s) is -0.504367
# Accuracy at 1700 paragraphs, 1 epoch,(104m 39s) is 0.504409
# Loss at 1750 paragraphs, 1 epoch,(107m 44s) is -0.503100
# Accuracy at 1750 paragraphs, 1 epoch,(107m 44s) is 0.503141
# Loss at 1800 paragraphs, 1 epoch,(110m 49s) is -0.506346
# Accuracy at 1800 paragraphs, 1 epoch,(110m 49s) is 0.506385
# Loss at 1850 paragraphs, 1 epoch,(113m 53s) is -0.504553
# Accuracy at 1850 paragraphs, 1 epoch,(113m 53s) is 0.504592
# Loss at 1900 paragraphs, 1 epoch,(116m 57s) is -0.501803
# Accuracy at 1900 paragraphs, 1 epoch,(116m 57s) is 0.501841
# Loss at 1950 paragraphs, 1 epoch,(120m 3s) is -0.501757
# Accuracy at 1950 paragraphs, 1 epoch,(120m 3s) is 0.501794
# Loss at 2000 paragraphs, 1 epoch,(123m 9s) is -0.498715
# Accuracy at 2000 paragraphs, 1 epoch,(123m 9s) is 0.498751
# Loss at 2050 paragraphs, 1 epoch,(126m 15s) is -0.496796
# Accuracy at 2050 paragraphs, 1 epoch,(126m 15s) is 0.496831
# Loss at 2100 paragraphs, 1 epoch,(129m 20s) is -0.496872
# Accuracy at 2100 paragraphs, 1 epoch,(129m 20s) is 0.496906
# Loss at 2150 paragraphs, 1 epoch,(132m 26s) is -0.495085
# Accuracy at 2150 paragraphs, 1 epoch,(132m 26s) is 0.495119
# Loss at 2200 paragraphs, 1 epoch,(135m 30s) is -0.494742
# Accuracy at 2200 paragraphs, 1 epoch,(135m 30s) is 0.494775
# Loss at 2250 paragraphs, 1 epoch,(138m 36s) is -0.495304
# Accuracy at 2250 paragraphs, 1 epoch,(138m 36s) is 0.495335
# Loss at 2300 paragraphs, 1 epoch,(141m 42s) is -0.494971
# Accuracy at 2300 paragraphs, 1 epoch,(141m 42s) is 0.495002
# Loss at 2350 paragraphs, 1 epoch,(144m 48s) is -0.493377
# Accuracy at 2350 paragraphs, 1 epoch,(144m 48s) is 0.493407
# Loss at 2400 paragraphs, 1 epoch,(147m 54s) is -0.496013
# Accuracy at 2400 paragraphs, 1 epoch,(147m 54s) is 0.496043
# Loss at 2450 paragraphs, 1 epoch,(151m 0s) is -0.495687
# Accuracy at 2450 paragraphs, 1 epoch,(151m 0s) is 0.495716
# Loss at 2500 paragraphs, 1 epoch,(154m 7s) is -0.496173
# Accuracy at 2500 paragraphs, 1 epoch,(154m 7s) is 0.496202
# Loss at 2550 paragraphs, 1 epoch,(157m 14s) is -0.495464
# Accuracy at 2550 paragraphs, 1 epoch,(157m 14s) is 0.495492
# Loss at 2600 paragraphs, 1 epoch,(160m 20s) is -0.492860
# Accuracy at 2600 paragraphs, 1 epoch,(160m 20s) is 0.492887
# Loss at 2650 paragraphs, 1 epoch,(163m 26s) is -0.493749
# Accuracy at 2650 paragraphs, 1 epoch,(163m 26s) is 0.493776
# Loss at 2700 paragraphs, 1 epoch,(166m 33s) is -0.494235
# Accuracy at 2700 paragraphs, 1 epoch,(166m 33s) is 0.494261
# Loss at 2750 paragraphs, 1 epoch,(169m 40s) is -0.492886
# Accuracy at 2750 paragraphs, 1 epoch,(169m 40s) is 0.492912
# Loss at 2800 paragraphs, 1 epoch,(172m 47s) is -0.493727
# Accuracy at 2800 paragraphs, 1 epoch,(172m 47s) is 0.493752
# Loss at 2850 paragraphs, 1 epoch,(175m 53s) is -0.494889
# Accuracy at 2850 paragraphs, 1 epoch,(175m 53s) is 0.494914
# Loss at 2900 paragraphs, 1 epoch,(178m 59s) is -0.495322
# Accuracy at 2900 paragraphs, 1 epoch,(178m 59s) is 0.495346
# Loss at 2950 paragraphs, 1 epoch,(182m 6s) is -0.495740
# Accuracy at 2950 paragraphs, 1 epoch,(182m 6s) is 0.495764
# Loss at 3000 paragraphs, 1 epoch,(185m 12s) is -0.494478
# Accuracy at 3000 paragraphs, 1 epoch,(185m 12s) is 0.494502
# Loss at 3050 paragraphs, 1 epoch,(188m 19s) is -0.495224
# Accuracy at 3050 paragraphs, 1 epoch,(188m 19s) is 0.495247
# Loss at 3100 paragraphs, 1 epoch,(191m 24s) is -0.495301
# Accuracy at 3100 paragraphs, 1 epoch,(191m 24s) is 0.495324
# Loss at 3150 paragraphs, 1 epoch,(194m 31s) is -0.499501
# Accuracy at 3150 paragraphs, 1 epoch,(194m 31s) is 0.499524
# Loss at 3200 paragraphs, 1 epoch,(197m 36s) is -0.501071
# Accuracy at 3200 paragraphs, 1 epoch,(197m 36s) is 0.501093
# Loss at 3250 paragraphs, 1 epoch,(200m 41s) is -0.498901
# Accuracy at 3250 paragraphs, 1 epoch,(200m 42s) is 0.498923
# Loss at 3300 paragraphs, 1 epoch,(203m 47s) is -0.499524
# Accuracy at 3300 paragraphs, 1 epoch,(203m 47s) is 0.499546
# Loss at 3350 paragraphs, 1 epoch,(206m 52s) is -0.498934
# Accuracy at 3350 paragraphs, 1 epoch,(206m 53s) is 0.498956
# Loss at 3400 paragraphs, 1 epoch,(209m 58s) is -0.499244
# Accuracy at 3400 paragraphs, 1 epoch,(209m 58s) is 0.499265
# Loss at 3450 paragraphs, 1 epoch,(213m 3s) is -0.498965
# Accuracy at 3450 paragraphs, 1 epoch,(213m 3s) is 0.498986
# Loss at 3500 paragraphs, 1 epoch,(216m 9s) is -0.498694
# Accuracy at 3500 paragraphs, 1 epoch,(216m 9s) is 0.498715
# Loss at 3550 paragraphs, 1 epoch,(219m 15s) is -0.498713
# Accuracy at 3550 paragraphs, 1 epoch,(219m 15s) is 0.498733
# Loss at 3600 paragraphs, 1 epoch,(222m 21s) is -0.498730
# Accuracy at 3600 paragraphs, 1 epoch,(222m 21s) is 0.498750
# Loss at 3650 paragraphs, 1 epoch,(225m 27s) is -0.499296
# Accuracy at 3650 paragraphs, 1 epoch,(225m 27s) is 0.499315
# Loss at 3700 paragraphs, 1 epoch,(228m 33s) is -0.500926
# Accuracy at 3700 paragraphs, 1 epoch,(228m 33s) is 0.500946
# Loss at 3750 paragraphs, 1 epoch,(231m 39s) is -0.500914
# Accuracy at 3750 paragraphs, 1 epoch,(231m 39s) is 0.500933
# Loss at 3800 paragraphs, 1 epoch,(234m 44s) is -0.501428
# Accuracy at 3800 paragraphs, 1 epoch,(234m 44s) is 0.501447
# Loss at 3850 paragraphs, 1 epoch,(237m 50s) is -0.501150
# Accuracy at 3850 paragraphs, 1 epoch,(237m 50s) is 0.501169
# Loss at 3900 paragraphs, 1 epoch,(240m 56s) is -0.500110
# Accuracy at 3900 paragraphs, 1 epoch,(240m 56s) is 0.500128
# Loss at 3950 paragraphs, 1 epoch,(244m 2s) is -0.498337
# Accuracy at 3950 paragraphs, 1 epoch,(244m 2s) is 0.498355
# Loss at 4000 paragraphs, 1 epoch,(247m 8s) is -0.500107
# Accuracy at 4000 paragraphs, 1 epoch,(247m 8s) is 0.500125
# Loss at 4050 paragraphs, 1 epoch,(250m 14s) is -0.500846
# Accuracy at 4050 paragraphs, 1 epoch,(250m 14s) is 0.500864
# Loss at 4100 paragraphs, 1 epoch,(253m 20s) is -0.500104
# Accuracy at 4100 paragraphs, 1 epoch,(253m 20s) is 0.500122
# Loss at 4150 paragraphs, 1 epoch,(256m 27s) is -0.500103
# Accuracy at 4150 paragraphs, 1 epoch,(256m 27s) is 0.500120
# Loss at 4200 paragraphs, 1 epoch,(259m 34s) is -0.500578
# Accuracy at 4200 paragraphs, 1 epoch,(259m 35s) is 0.500595
# Loss at 4250 paragraphs, 1 epoch,(262m 41s) is -0.501747
# Accuracy at 4250 paragraphs, 1 epoch,(262m 41s) is 0.501764
# Loss at 4300 paragraphs, 1 epoch,(265m 49s) is -0.501960
# Accuracy at 4300 paragraphs, 1 epoch,(265m 49s) is 0.501976
# Loss at 4350 paragraphs, 1 epoch,(268m 55s) is -0.501937
# Accuracy at 4350 paragraphs, 1 epoch,(268m 55s) is 0.501954
# Loss at 4400 paragraphs, 1 epoch,(272m 2s) is -0.502370
# Accuracy at 4400 paragraphs, 1 epoch,(272m 2s) is 0.502386
# Loss at 4450 paragraphs, 1 epoch,(275m 10s) is -0.503916
# Accuracy at 4450 paragraphs, 1 epoch,(275m 10s) is 0.503932
# Loss at 4500 paragraphs, 1 epoch,(278m 17s) is -0.504983
# Accuracy at 4500 paragraphs, 1 epoch,(278m 17s) is 0.504999
# Loss at 4550 paragraphs, 1 epoch,(281m 25s) is -0.505807
# Accuracy at 4550 paragraphs, 1 epoch,(281m 25s) is 0.505823
# Loss at 4600 paragraphs, 1 epoch,(284m 32s) is -0.505309
# Accuracy at 4600 paragraphs, 1 epoch,(284m 32s) is 0.505325
# Loss at 4650 paragraphs, 1 epoch,(287m 39s) is -0.504822
# Accuracy at 4650 paragraphs, 1 epoch,(287m 39s) is 0.504838
# Loss at 4700 paragraphs, 1 epoch,(290m 46s) is -0.504984
# Accuracy at 4700 paragraphs, 1 epoch,(290m 46s) is 0.504999
# Loss at 4750 paragraphs, 1 epoch,(293m 53s) is -0.504931
# Accuracy at 4750 paragraphs, 1 epoch,(293m 53s) is 0.504946
# Loss at 4800 paragraphs, 1 epoch,(297m 0s) is -0.505921
# Accuracy at 4800 paragraphs, 1 epoch,(297m 0s) is 0.505936
# Loss at 4850 paragraphs, 1 epoch,(300m 6s) is -0.505242
# Accuracy at 4850 paragraphs, 1 epoch,(300m 6s) is 0.505257
# Loss at 4900 paragraphs, 1 epoch,(303m 12s) is -0.505392
# Accuracy at 4900 paragraphs, 1 epoch,(303m 12s) is 0.505407
# Loss at 4950 paragraphs, 1 epoch,(306m 18s) is -0.504530
# Accuracy at 4950 paragraphs, 1 epoch,(306m 18s) is 0.504545
# Loss at 5000 paragraphs, 1 epoch,(309m 24s) is -0.504485
# Accuracy at 5000 paragraphs, 1 epoch,(309m 24s) is 0.504499
# Loss at 5050 paragraphs, 1 epoch,(312m 30s) is -0.503648
# Accuracy at 5050 paragraphs, 1 epoch,(312m 30s) is 0.503663
# Loss at 5100 paragraphs, 1 epoch,(315m 36s) is -0.503025
# Accuracy at 5100 paragraphs, 1 epoch,(315m 36s) is 0.503039
# Loss at 5150 paragraphs, 1 epoch,(318m 42s) is -0.503772
# Accuracy at 5150 paragraphs, 1 epoch,(318m 42s) is 0.503786
# Loss at 5200 paragraphs, 1 epoch,(321m 52s) is -0.503735
# Accuracy at 5200 paragraphs, 1 epoch,(321m 52s) is 0.503749
# Loss at 5250 paragraphs, 1 epoch,(325m 5s) is -0.503509
# Accuracy at 5250 paragraphs, 1 epoch,(325m 5s) is 0.503523
# Loss at 5300 paragraphs, 1 epoch,(328m 17s) is -0.503288
# Accuracy at 5300 paragraphs, 1 epoch,(328m 17s) is 0.503301
# Loss at 5350 paragraphs, 1 epoch,(331m 28s) is -0.503070
# Accuracy at 5350 paragraphs, 1 epoch,(331m 28s) is 0.503084
# Loss at 5400 paragraphs, 1 epoch,(334m 40s) is -0.503967
# Accuracy at 5400 paragraphs, 1 epoch,(334m 40s) is 0.503981
# Loss at 5450 paragraphs, 1 epoch,(337m 52s) is -0.504665
# Accuracy at 5450 paragraphs, 1 epoch,(337m 52s) is 0.504678
# Loss at 5500 paragraphs, 1 epoch,(341m 4s) is -0.504986
# Accuracy at 5500 paragraphs, 1 epoch,(341m 4s) is 0.504999
# Loss at 5550 paragraphs, 1 epoch,(344m 16s) is -0.504401
# Accuracy at 5550 paragraphs, 1 epoch,(344m 16s) is 0.504414
# Loss at 5600 paragraphs, 1 epoch,(347m 28s) is -0.504004
# Accuracy at 5600 paragraphs, 1 epoch,(347m 28s) is 0.504017
# Loss at 5650 paragraphs, 1 epoch,(350m 39s) is -0.503615
# Accuracy at 5650 paragraphs, 1 epoch,(350m 39s) is 0.503628
# Loss at 5700 paragraphs, 1 epoch,(353m 51s) is -0.503759
# Accuracy at 5700 paragraphs, 1 epoch,(353m 51s) is 0.503771
# Loss at 5750 paragraphs, 1 epoch,(357m 3s) is -0.502683
# Accuracy at 5750 paragraphs, 1 epoch,(357m 3s) is 0.502695
# Loss at 5800 paragraphs, 1 epoch,(360m 15s) is -0.502487
# Accuracy at 5800 paragraphs, 1 epoch,(360m 15s) is 0.502500
# Loss at 5850 paragraphs, 1 epoch,(363m 28s) is -0.502637
# Accuracy at 5850 paragraphs, 1 epoch,(363m 28s) is 0.502649
# Loss at 5900 paragraphs, 1 epoch,(366m 40s) is -0.502784
# Accuracy at 5900 paragraphs, 1 epoch,(366m 40s) is 0.502796
# Loss at 5950 paragraphs, 1 epoch,(369m 53s) is -0.502593
# Accuracy at 5950 paragraphs, 1 epoch,(369m 53s) is 0.502605
# Loss at 6000 paragraphs, 1 epoch,(373m 5s) is -0.503737
# Accuracy at 6000 paragraphs, 1 epoch,(373m 5s) is 0.503749
# Loss at 6050 paragraphs, 1 epoch,(376m 17s) is -0.504202
# Accuracy at 6050 paragraphs, 1 epoch,(376m 17s) is 0.504214
# Loss at 6100 paragraphs, 1 epoch,(379m 29s) is -0.503676
# Accuracy at 6100 paragraphs, 1 epoch,(379m 29s) is 0.503688
# Loss at 6150 paragraphs, 1 epoch,(382m 40s) is -0.502833
# Accuracy at 6150 paragraphs, 1 epoch,(382m 40s) is 0.502845
# Loss at 6200 paragraphs, 1 epoch,(385m 53s) is -0.503778
# Accuracy at 6200 paragraphs, 1 epoch,(385m 53s) is 0.503790
# Loss at 6250 paragraphs, 1 epoch,(389m 4s) is -0.502468
# Accuracy at 6250 paragraphs, 1 epoch,(389m 5s) is 0.502480
# Loss at 6300 paragraphs, 1 epoch,(392m 16s) is -0.503242
# Accuracy at 6300 paragraphs, 1 epoch,(392m 17s) is 0.503253
# Loss at 6350 paragraphs, 1 epoch,(395m 28s) is -0.503374
# Accuracy at 6350 paragraphs, 1 epoch,(395m 28s) is 0.503385
# Loss at 6400 paragraphs, 1 epoch,(398m 40s) is -0.503191
# Accuracy at 6400 paragraphs, 1 epoch,(398m 40s) is 0.503203
# Loss at 6450 paragraphs, 1 epoch,(401m 52s) is -0.503787
# Accuracy at 6450 paragraphs, 1 epoch,(401m 52s) is 0.503798
# Loss at 6500 paragraphs, 1 epoch,(405m 4s) is -0.503296
# Accuracy at 6500 paragraphs, 1 epoch,(405m 4s) is 0.503307
# Loss at 6550 paragraphs, 1 epoch,(408m 16s) is -0.503576
# Accuracy at 6550 paragraphs, 1 epoch,(408m 16s) is 0.503587
# Loss at 6600 paragraphs, 1 epoch,(411m 28s) is -0.503095
# Accuracy at 6600 paragraphs, 1 epoch,(411m 28s) is 0.503106
# Loss at 6650 paragraphs, 1 epoch,(414m 39s) is -0.503372
# Accuracy at 6650 paragraphs, 1 epoch,(414m 39s) is 0.503383
# Loss at 6700 paragraphs, 1 epoch,(417m 51s) is -0.503049
# Accuracy at 6700 paragraphs, 1 epoch,(417m 51s) is 0.503059
# Loss at 6750 paragraphs, 1 epoch,(421m 4s) is -0.503767
# Accuracy at 6750 paragraphs, 1 epoch,(421m 4s) is 0.503777
# Loss at 6800 paragraphs, 1 epoch,(424m 17s) is -0.503298
# Accuracy at 6800 paragraphs, 1 epoch,(424m 17s) is 0.503308
# Loss at 6850 paragraphs, 1 epoch,(427m 29s) is -0.503566
# Accuracy at 6850 paragraphs, 1 epoch,(427m 29s) is 0.503576
# Loss at 6900 paragraphs, 1 epoch,(430m 41s) is -0.503395
# Accuracy at 6900 paragraphs, 1 epoch,(430m 41s) is 0.503405
# Loss at 6950 paragraphs, 1 epoch,(433m 52s) is -0.503946
# Accuracy at 6950 paragraphs, 1 epoch,(433m 52s) is 0.503956
# Loss at 7000 paragraphs, 1 epoch,(437m 5s) is -0.504489
# Accuracy at 7000 paragraphs, 1 epoch,(437m 5s) is 0.504499
# Loss at 7050 paragraphs, 1 epoch,(440m 18s) is -0.505450
# Accuracy at 7050 paragraphs, 1 epoch,(440m 18s) is 0.505460
# Loss at 7100 paragraphs, 1 epoch,(443m 30s) is -0.505271
# Accuracy at 7100 paragraphs, 1 epoch,(443m 30s) is 0.505281
# Loss at 7150 paragraphs, 1 epoch,(446m 41s) is -0.504535
# Accuracy at 7150 paragraphs, 1 epoch,(446m 42s) is 0.504545
# Loss at 7200 paragraphs, 1 epoch,(449m 53s) is -0.505475
# Accuracy at 7200 paragraphs, 1 epoch,(449m 53s) is 0.505485
# Loss at 7250 paragraphs, 1 epoch,(453m 5s) is -0.505438
# Accuracy at 7250 paragraphs, 1 epoch,(453m 6s) is 0.505448
# Loss at 7300 paragraphs, 1 epoch,(456m 17s) is -0.504990
# Accuracy at 7300 paragraphs, 1 epoch,(456m 17s) is 0.504999
# Loss at 7350 paragraphs, 1 epoch,(459m 29s) is -0.505092
# Accuracy at 7350 paragraphs, 1 epoch,(459m 29s) is 0.505101
# Loss at 7400 paragraphs, 1 epoch,(462m 42s) is -0.504922
# Accuracy at 7400 paragraphs, 1 epoch,(462m 42s) is 0.504932
# Loss at 7450 paragraphs, 1 epoch,(465m 54s) is -0.504889
# Accuracy at 7450 paragraphs, 1 epoch,(465m 54s) is 0.504899
# Loss at 7500 paragraphs, 1 epoch,(469m 6s) is -0.505256
# Accuracy at 7500 paragraphs, 1 epoch,(469m 6s) is 0.505266
# Loss at 7550 paragraphs, 1 epoch,(472m 19s) is -0.505222
# Accuracy at 7550 paragraphs, 1 epoch,(472m 19s) is 0.505231
# Loss at 7600 paragraphs, 1 epoch,(475m 34s) is -0.505187
# Accuracy at 7600 paragraphs, 1 epoch,(475m 34s) is 0.505197
# Loss at 7650 paragraphs, 1 epoch,(478m 48s) is -0.505676
# Accuracy at 7650 paragraphs, 1 epoch,(478m 48s) is 0.505686
# Loss at 7700 paragraphs, 1 epoch,(482m 1s) is -0.506029
# Accuracy at 7700 paragraphs, 1 epoch,(482m 2s) is 0.506038
# Loss at 7750 paragraphs, 1 epoch,(485m 15s) is -0.506506
# Accuracy at 7750 paragraphs, 1 epoch,(485m 15s) is 0.506515
# Loss at 7800 paragraphs, 1 epoch,(488m 29s) is -0.507105
# Accuracy at 7800 paragraphs, 1 epoch,(488m 29s) is 0.507114
# Loss at 7850 paragraphs, 1 epoch,(491m 43s) is -0.506551
# Accuracy at 7850 paragraphs, 1 epoch,(491m 43s) is 0.506560
# Loss at 7900 paragraphs, 1 epoch,(494m 57s) is -0.506509
# Accuracy at 7900 paragraphs, 1 epoch,(494m 57s) is 0.506518
# Loss at 7950 paragraphs, 1 epoch,(498m 12s) is -0.506720
# Accuracy at 7950 paragraphs, 1 epoch,(498m 12s) is 0.506729
# Loss at 8000 paragraphs, 1 epoch,(501m 26s) is -0.506428
# Accuracy at 8000 paragraphs, 1 epoch,(501m 26s) is 0.506437
# Loss at 8050 paragraphs, 1 epoch,(504m 40s) is -0.507506
# Accuracy at 8050 paragraphs, 1 epoch,(504m 40s) is 0.507515
# Loss at 8100 paragraphs, 1 epoch,(507m 54s) is -0.507459
# Accuracy at 8100 paragraphs, 1 epoch,(507m 54s) is 0.507468
# Loss at 8150 paragraphs, 1 epoch,(511m 7s) is -0.507046
# Accuracy at 8150 paragraphs, 1 epoch,(511m 7s) is 0.507054
# Loss at 8200 paragraphs, 1 epoch,(514m 21s) is -0.506759
# Accuracy at 8200 paragraphs, 1 epoch,(514m 21s) is 0.506767
# Loss at 8250 paragraphs, 1 epoch,(517m 35s) is -0.506839
# Accuracy at 8250 paragraphs, 1 epoch,(517m 36s) is 0.506848
# Loss at 8300 paragraphs, 1 epoch,(520m 50s) is -0.506436
# Accuracy at 8300 paragraphs, 1 epoch,(520m 50s) is 0.506445
# Loss at 8350 paragraphs, 1 epoch,(524m 3s) is -0.506158
# Accuracy at 8350 paragraphs, 1 epoch,(524m 3s) is 0.506167
# Loss at 8400 paragraphs, 1 epoch,(527m 17s) is -0.505884
# Accuracy at 8400 paragraphs, 1 epoch,(527m 17s) is 0.505892
# Loss at 8450 paragraphs, 1 epoch,(530m 29s) is -0.505376
# Accuracy at 8450 paragraphs, 1 epoch,(530m 29s) is 0.505384
# Loss at 8500 paragraphs, 1 epoch,(533m 43s) is -0.504756
# Accuracy at 8500 paragraphs, 1 epoch,(533m 43s) is 0.504764
# Loss at 8550 paragraphs, 1 epoch,(536m 56s) is -0.504845
# Accuracy at 8550 paragraphs, 1 epoch,(536m 56s) is 0.504853
# Loss at 8600 paragraphs, 1 epoch,(540m 9s) is -0.504817
# Accuracy at 8600 paragraphs, 1 epoch,(540m 9s) is 0.504825
# Loss at 8650 paragraphs, 1 epoch,(543m 22s) is -0.503748
# Accuracy at 8650 paragraphs, 1 epoch,(543m 22s) is 0.503757
# Loss at 8700 paragraphs, 1 epoch,(546m 35s) is -0.503842
# Accuracy at 8700 paragraphs, 1 epoch,(546m 35s) is 0.503850
# Loss at 8750 paragraphs, 1 epoch,(549m 49s) is -0.503820
# Accuracy at 8750 paragraphs, 1 epoch,(549m 49s) is 0.503828
# Loss at 8800 paragraphs, 1 epoch,(553m 2s) is -0.503571
# Accuracy at 8800 paragraphs, 1 epoch,(553m 2s) is 0.503579
# Loss at 8850 paragraphs, 1 epoch,(556m 15s) is -0.504568
# Accuracy at 8850 paragraphs, 1 epoch,(556m 15s) is 0.504576
# Loss at 8900 paragraphs, 1 epoch,(559m 28s) is -0.504542
# Accuracy at 8900 paragraphs, 1 epoch,(559m 28s) is 0.504550
# Loss at 8950 paragraphs, 1 epoch,(562m 42s) is -0.504405
# Accuracy at 8950 paragraphs, 1 epoch,(562m 42s) is 0.504413
# Loss at 9000 paragraphs, 1 epoch,(565m 55s) is -0.504603
# Accuracy at 9000 paragraphs, 1 epoch,(565m 55s) is 0.504611
# Loss at 9050 paragraphs, 1 epoch,(569m 8s) is -0.505130
# Accuracy at 9050 paragraphs, 1 epoch,(569m 8s) is 0.505138
# Loss at 9100 paragraphs, 1 epoch,(572m 16s) is -0.504222
# Accuracy at 9100 paragraphs, 1 epoch,(572m 16s) is 0.504230
# Loss at 9150 paragraphs, 1 epoch,(575m 24s) is -0.503872
# Accuracy at 9150 paragraphs, 1 epoch,(575m 24s) is 0.503879
# Loss at 9200 paragraphs, 1 epoch,(578m 32s) is -0.503742
# Accuracy at 9200 paragraphs, 1 epoch,(578m 32s) is 0.503750
# Loss at 9250 paragraphs, 1 epoch,(581m 40s) is -0.503505
# Accuracy at 9250 paragraphs, 1 epoch,(581m 40s) is 0.503513
# Loss at 9300 paragraphs, 1 epoch,(584m 47s) is -0.503056
# Accuracy at 9300 paragraphs, 1 epoch,(584m 47s) is 0.503064
# Loss at 9350 paragraphs, 1 epoch,(587m 55s) is -0.503040
# Accuracy at 9350 paragraphs, 1 epoch,(587m 55s) is 0.503048
# Loss at 9400 paragraphs, 1 epoch,(591m 2s) is -0.503343
# Accuracy at 9400 paragraphs, 1 epoch,(591m 2s) is 0.503351
# Loss at 9450 paragraphs, 1 epoch,(594m 9s) is -0.503854
# Accuracy at 9450 paragraphs, 1 epoch,(594m 9s) is 0.503862
# Loss at 9500 paragraphs, 1 epoch,(597m 16s) is -0.503308
# Accuracy at 9500 paragraphs, 1 epoch,(597m 16s) is 0.503315
# Loss at 9550 paragraphs, 1 epoch,(600m 23s) is -0.502872
# Accuracy at 9550 paragraphs, 1 epoch,(600m 23s) is 0.502879
# Loss at 9600 paragraphs, 1 epoch,(603m 31s) is -0.502961
# Accuracy at 9600 paragraphs, 1 epoch,(603m 31s) is 0.502968
# Loss at 9650 paragraphs, 1 epoch,(606m 38s) is -0.503360
# Accuracy at 9650 paragraphs, 1 epoch,(606m 38s) is 0.503368
# Loss at 9700 paragraphs, 1 epoch,(609m 45s) is -0.503652
# Accuracy at 9700 paragraphs, 1 epoch,(609m 45s) is 0.503659
# Loss at 9750 paragraphs, 1 epoch,(612m 52s) is -0.503838
# Accuracy at 9750 paragraphs, 1 epoch,(612m 52s) is 0.503846
# Loss at 9800 paragraphs, 1 epoch,(616m 0s) is -0.503819
# Accuracy at 9800 paragraphs, 1 epoch,(616m 0s) is 0.503826
# Loss at 9850 paragraphs, 1 epoch,(619m 7s) is -0.503901
# Accuracy at 9850 paragraphs, 1 epoch,(619m 7s) is 0.503908
# Loss at 9900 paragraphs, 1 epoch,(622m 15s) is -0.504184
# Accuracy at 9900 paragraphs, 1 epoch,(622m 15s) is 0.504191
# Loss at 9950 paragraphs, 1 epoch,(625m 22s) is -0.504565
# Accuracy at 9950 paragraphs, 1 epoch,(625m 22s) is 0.504572
# Loss at 10000 paragraphs, 1 epoch,(628m 30s) is -0.504442
# Accuracy at 10000 paragraphs, 1 epoch,(628m 31s) is 0.504450
# Loss at 10050 paragraphs, 1 epoch,(631m 39s) is -0.504420
# Accuracy at 10050 paragraphs, 1 epoch,(631m 39s) is 0.504427
# Loss at 10100 paragraphs, 1 epoch,(634m 48s) is -0.504200
# Accuracy at 10100 paragraphs, 1 epoch,(634m 48s) is 0.504208
# Loss at 10150 paragraphs, 1 epoch,(637m 56s) is -0.504672
# Accuracy at 10150 paragraphs, 1 epoch,(637m 56s) is 0.504679
# Loss at 10200 paragraphs, 1 epoch,(641m 3s) is -0.505140
# Accuracy at 10200 paragraphs, 1 epoch,(641m 3s) is 0.505147
# Loss at 10250 paragraphs, 1 epoch,(644m 11s) is -0.504919
# Accuracy at 10250 paragraphs, 1 epoch,(644m 11s) is 0.504926
# Loss at 10300 paragraphs, 1 epoch,(647m 20s) is -0.504313
# Accuracy at 10300 paragraphs, 1 epoch,(647m 20s) is 0.504320
# Loss at 10350 paragraphs, 1 epoch,(650m 28s) is -0.504872
# Accuracy at 10350 paragraphs, 1 epoch,(650m 28s) is 0.504879
# Loss at 10400 paragraphs, 1 epoch,(653m 37s) is -0.505618
# Accuracy at 10400 paragraphs, 1 epoch,(653m 37s) is 0.505624
# Loss at 10450 paragraphs, 1 epoch,(656m 45s) is -0.505495
# Accuracy at 10450 paragraphs, 1 epoch,(656m 45s) is 0.505502
# Loss at 10500 paragraphs, 1 epoch,(659m 53s) is -0.504612
# Accuracy at 10500 paragraphs, 1 epoch,(659m 53s) is 0.504619
# Loss at 10550 paragraphs, 1 epoch,(663m 0s) is -0.505159
# Accuracy at 10550 paragraphs, 1 epoch,(663m 0s) is 0.505165
# Loss at 10600 paragraphs, 1 epoch,(666m 7s) is -0.505700
# Accuracy at 10600 paragraphs, 1 epoch,(666m 7s) is 0.505707
# Loss at 10650 paragraphs, 1 epoch,(669m 15s) is -0.505955
# Accuracy at 10650 paragraphs, 1 epoch,(669m 15s) is 0.505962
# Loss at 10700 paragraphs, 1 epoch,(672m 23s) is -0.505554
# Accuracy at 10700 paragraphs, 1 epoch,(672m 23s) is 0.505560
# Loss at 10750 paragraphs, 1 epoch,(675m 29s) is -0.504970
# Accuracy at 10750 paragraphs, 1 epoch,(675m 29s) is 0.504976
# Loss at 10800 paragraphs, 1 epoch,(678m 36s) is -0.504391
# Accuracy at 10800 paragraphs, 1 epoch,(678m 36s) is 0.504398
# Loss at 10850 paragraphs, 1 epoch,(681m 43s) is -0.504094
# Accuracy at 10850 paragraphs, 1 epoch,(681m 43s) is 0.504101
# Loss at 10900 paragraphs, 1 epoch,(684m 50s) is -0.504167
# Accuracy at 10900 paragraphs, 1 epoch,(684m 50s) is 0.504174
# Loss at 10950 paragraphs, 1 epoch,(687m 57s) is -0.504514
# Accuracy at 10950 paragraphs, 1 epoch,(687m 57s) is 0.504520
# Loss at 11000 paragraphs, 1 epoch,(691m 4s) is -0.504402
# Accuracy at 11000 paragraphs, 1 epoch,(691m 4s) is 0.504409
# Loss at 11050 paragraphs, 1 epoch,(694m 11s) is -0.504382
# Accuracy at 11050 paragraphs, 1 epoch,(694m 11s) is 0.504389
# Loss at 11100 paragraphs, 1 epoch,(697m 18s) is -0.504453
# Accuracy at 11100 paragraphs, 1 epoch,(697m 18s) is 0.504459
# Loss at 11150 paragraphs, 1 epoch,(700m 25s) is -0.504612
# Accuracy at 11150 paragraphs, 1 epoch,(700m 25s) is 0.504618
# Loss at 11200 paragraphs, 1 epoch,(703m 32s) is -0.504859
# Accuracy at 11200 paragraphs, 1 epoch,(703m 32s) is 0.504866
# Loss at 11250 paragraphs, 1 epoch,(706m 39s) is -0.505104
# Accuracy at 11250 paragraphs, 1 epoch,(706m 39s) is 0.505111
# Loss at 11300 paragraphs, 1 epoch,(709m 46s) is -0.505170
# Accuracy at 11300 paragraphs, 1 epoch,(709m 46s) is 0.505177
# Loss at 11350 paragraphs, 1 epoch,(712m 53s) is -0.505147
# Accuracy at 11350 paragraphs, 1 epoch,(712m 53s) is 0.505154
# Loss at 11400 paragraphs, 1 epoch,(716m 0s) is -0.505213
# Accuracy at 11400 paragraphs, 1 epoch,(716m 0s) is 0.505219
# Loss at 11450 paragraphs, 1 epoch,(719m 7s) is -0.505277
# Accuracy at 11450 paragraphs, 1 epoch,(719m 7s) is 0.505283
# Loss at 11500 paragraphs, 1 epoch,(722m 14s) is -0.505341
# Accuracy at 11500 paragraphs, 1 epoch,(722m 14s) is 0.505347
# Loss at 11550 paragraphs, 1 epoch,(725m 20s) is -0.504972
# Accuracy at 11550 paragraphs, 1 epoch,(725m 21s) is 0.504978
# Loss at 11600 paragraphs, 1 epoch,(728m 28s) is -0.504864
# Accuracy at 11600 paragraphs, 1 epoch,(728m 28s) is 0.504870
# Loss at 11650 paragraphs, 1 epoch,(731m 35s) is -0.504672
# Accuracy at 11650 paragraphs, 1 epoch,(731m 35s) is 0.504678
# Loss at 11700 paragraphs, 1 epoch,(734m 42s) is -0.504737
# Accuracy at 11700 paragraphs, 1 epoch,(734m 42s) is 0.504743
# Loss at 11750 paragraphs, 1 epoch,(737m 49s) is -0.504802
# Accuracy at 11750 paragraphs, 1 epoch,(737m 49s) is 0.504808
# Loss at 11800 paragraphs, 1 epoch,(740m 56s) is -0.504782
# Accuracy at 11800 paragraphs, 1 epoch,(740m 57s) is 0.504788
# Loss at 11850 paragraphs, 1 epoch,(744m 4s) is -0.505183
# Accuracy at 11850 paragraphs, 1 epoch,(744m 4s) is 0.505189
# Loss at 11900 paragraphs, 1 epoch,(747m 11s) is -0.504994
# Accuracy at 11900 paragraphs, 1 epoch,(747m 11s) is 0.505000
# Loss at 11950 paragraphs, 1 epoch,(750m 18s) is -0.505140
# Accuracy at 11950 paragraphs, 1 epoch,(750m 18s) is 0.505146
# Loss at 12000 paragraphs, 1 epoch,(753m 25s) is -0.505285
# Accuracy at 12000 paragraphs, 1 epoch,(753m 25s) is 0.505291
# Loss at 12050 paragraphs, 1 epoch,(756m 33s) is -0.504931
# Accuracy at 12050 paragraphs, 1 epoch,(756m 33s) is 0.504937
# Loss at 12100 paragraphs, 1 epoch,(759m 41s) is -0.504663
# Accuracy at 12100 paragraphs, 1 epoch,(759m 41s) is 0.504669
# Loss at 12150 paragraphs, 1 epoch,(762m 48s) is -0.504644
# Accuracy at 12150 paragraphs, 1 epoch,(762m 48s) is 0.504650
# Loss at 12200 paragraphs, 1 epoch,(765m 55s) is -0.504625
# Accuracy at 12200 paragraphs, 1 epoch,(765m 55s) is 0.504631
# Loss at 12250 paragraphs, 1 epoch,(769m 2s) is -0.504851
# Accuracy at 12250 paragraphs, 1 epoch,(769m 2s) is 0.504857
# Loss at 12300 paragraphs, 1 epoch,(772m 10s) is -0.505075
# Accuracy at 12300 paragraphs, 1 epoch,(772m 10s) is 0.505081
# Loss at 12350 paragraphs, 1 epoch,(775m 17s) is -0.504812
# Accuracy at 12350 paragraphs, 1 epoch,(775m 17s) is 0.504817
# Loss at 12400 paragraphs, 1 epoch,(778m 24s) is -0.504954
# Accuracy at 12400 paragraphs, 1 epoch,(778m 24s) is 0.504959
# Loss at 12450 paragraphs, 1 epoch,(781m 32s) is -0.505255
# Accuracy at 12450 paragraphs, 1 epoch,(781m 32s) is 0.505261
# Loss at 12500 paragraphs, 1 epoch,(784m 39s) is -0.505634
# Accuracy at 12500 paragraphs, 1 epoch,(784m 39s) is 0.505640
# Loss at 12550 paragraphs, 1 epoch,(787m 47s) is -0.505611
# Accuracy at 12550 paragraphs, 1 epoch,(787m 47s) is 0.505617
# Loss at 12600 paragraphs, 1 epoch,(790m 54s) is -0.505748
# Accuracy at 12600 paragraphs, 1 epoch,(790m 54s) is 0.505754
# Loss at 12650 paragraphs, 1 epoch,(794m 2s) is -0.505646
# Accuracy at 12650 paragraphs, 1 epoch,(794m 2s) is 0.505652
# Loss at 12700 paragraphs, 1 epoch,(797m 10s) is -0.505860
# Accuracy at 12700 paragraphs, 1 epoch,(797m 10s) is 0.505866
# Loss at 12750 paragraphs, 1 epoch,(800m 18s) is -0.506072
# Accuracy at 12750 paragraphs, 1 epoch,(800m 18s) is 0.506078
# Loss at 12800 paragraphs, 1 epoch,(803m 25s) is -0.506127
# Accuracy at 12800 paragraphs, 1 epoch,(803m 25s) is 0.506132
# Loss at 12850 paragraphs, 1 epoch,(806m 32s) is -0.505636
# Accuracy at 12850 paragraphs, 1 epoch,(806m 32s) is 0.505642
# Loss at 12900 paragraphs, 1 epoch,(809m 39s) is -0.506079
# Accuracy at 12900 paragraphs, 1 epoch,(809m 39s) is 0.506085
# Loss at 12950 paragraphs, 1 epoch,(812m 47s) is -0.506365
# Accuracy at 12950 paragraphs, 1 epoch,(812m 47s) is 0.506370
# Loss at 13000 paragraphs, 1 epoch,(815m 55s) is -0.506263
# Accuracy at 13000 paragraphs, 1 epoch,(815m 55s) is 0.506269
# Loss at 13050 paragraphs, 1 epoch,(819m 3s) is -0.506392
# Accuracy at 13050 paragraphs, 1 epoch,(819m 3s) is 0.506398
# Loss at 13100 paragraphs, 1 epoch,(822m 10s) is -0.506139
# Accuracy at 13100 paragraphs, 1 epoch,(822m 10s) is 0.506145
# Loss at 13150 paragraphs, 1 epoch,(825m 17s) is -0.506268
# Accuracy at 13150 paragraphs, 1 epoch,(825m 17s) is 0.506273
# Loss at 13200 paragraphs, 1 epoch,(828m 24s) is -0.506547
# Accuracy at 13200 paragraphs, 1 epoch,(828m 25s) is 0.506553
# Loss at 13250 paragraphs, 1 epoch,(831m 32s) is -0.506975
# Accuracy at 13250 paragraphs, 1 epoch,(831m 32s) is 0.506981
# Loss at 13300 paragraphs, 1 epoch,(834m 40s) is -0.506723
# Accuracy at 13300 paragraphs, 1 epoch,(834m 40s) is 0.506729
# Loss at 13350 paragraphs, 1 epoch,(837m 49s) is -0.506848
# Accuracy at 13350 paragraphs, 1 epoch,(837m 49s) is 0.506853
# Loss at 13400 paragraphs, 1 epoch,(840m 58s) is -0.506822
# Accuracy at 13400 paragraphs, 1 epoch,(840m 58s) is 0.506828
# Loss at 13450 paragraphs, 1 epoch,(844m 7s) is -0.506574
# Accuracy at 13450 paragraphs, 1 epoch,(844m 7s) is 0.506579
# Loss at 13500 paragraphs, 1 epoch,(847m 15s) is -0.506550
# Accuracy at 13500 paragraphs, 1 epoch,(847m 15s) is 0.506555
# Loss at 13550 paragraphs, 1 epoch,(850m 23s) is -0.506599
# Accuracy at 13550 paragraphs, 1 epoch,(850m 23s) is 0.506605
# Loss at 13600 paragraphs, 1 epoch,(853m 31s) is -0.506355
# Accuracy at 13600 paragraphs, 1 epoch,(853m 31s) is 0.506360
# Loss at 13650 paragraphs, 1 epoch,(856m 40s) is -0.505892
# Accuracy at 13650 paragraphs, 1 epoch,(856m 40s) is 0.505897
# Loss at 13700 paragraphs, 1 epoch,(859m 49s) is -0.505140
# Accuracy at 13700 paragraphs, 1 epoch,(859m 49s) is 0.505146
# Loss at 13750 paragraphs, 1 epoch,(862m 57s) is -0.505413
# Accuracy at 13750 paragraphs, 1 epoch,(862m 57s) is 0.505418
# Loss at 13800 paragraphs, 1 epoch,(866m 5s) is -0.505393
# Accuracy at 13800 paragraphs, 1 epoch,(866m 5s) is 0.505398
# Loss at 13850 paragraphs, 1 epoch,(869m 14s) is -0.505301
# Accuracy at 13850 paragraphs, 1 epoch,(869m 14s) is 0.505306
# Loss at 13900 paragraphs, 1 epoch,(872m 22s) is -0.505498
# Accuracy at 13900 paragraphs, 1 epoch,(872m 22s) is 0.505503
# Loss at 13950 paragraphs, 1 epoch,(875m 29s) is -0.505478
# Accuracy at 13950 paragraphs, 1 epoch,(875m 29s) is 0.505483
# Loss at 14000 paragraphs, 1 epoch,(878m 37s) is -0.505602
# Accuracy at 14000 paragraphs, 1 epoch,(878m 37s) is 0.505607
# Loss at 14050 paragraphs, 1 epoch,(881m 45s) is -0.506009
# Accuracy at 14050 paragraphs, 1 epoch,(881m 45s) is 0.506014
# Loss at 14100 paragraphs, 1 epoch,(884m 53s) is -0.505987
# Accuracy at 14100 paragraphs, 1 epoch,(884m 53s) is 0.505992
# Loss at 14150 paragraphs, 1 epoch,(888m 0s) is -0.505825
# Accuracy at 14150 paragraphs, 1 epoch,(888m 0s) is 0.505830
# Loss at 14200 paragraphs, 1 epoch,(891m 8s) is -0.506086
# Accuracy at 14200 paragraphs, 1 epoch,(891m 8s) is 0.506091
# Loss at 14250 paragraphs, 1 epoch,(894m 16s) is -0.506135
# Accuracy at 14250 paragraphs, 1 epoch,(894m 16s) is 0.506140
# Loss at 14300 paragraphs, 1 epoch,(897m 24s) is -0.506533
# Accuracy at 14300 paragraphs, 1 epoch,(897m 25s) is 0.506538
# Loss at 14350 paragraphs, 1 epoch,(900m 34s) is -0.506301
# Accuracy at 14350 paragraphs, 1 epoch,(900m 34s) is 0.506306
# Loss at 14400 paragraphs, 1 epoch,(903m 43s) is -0.506418
# Accuracy at 14400 paragraphs, 1 epoch,(903m 43s) is 0.506423
# Loss at 14450 paragraphs, 1 epoch,(906m 51s) is -0.506258
# Accuracy at 14450 paragraphs, 1 epoch,(906m 51s) is 0.506263
# Loss at 14500 paragraphs, 1 epoch,(910m 0s) is -0.506098
# Accuracy at 14500 paragraphs, 1 epoch,(910m 0s) is 0.506103
# Loss at 14550 paragraphs, 1 epoch,(913m 10s) is -0.506352
# Accuracy at 14550 paragraphs, 1 epoch,(913m 10s) is 0.506357
# Loss at 14600 paragraphs, 1 epoch,(916m 20s) is -0.506330
# Accuracy at 14600 paragraphs, 1 epoch,(916m 20s) is 0.506335
# Loss at 14650 paragraphs, 1 epoch,(919m 29s) is -0.506786
# Accuracy at 14650 paragraphs, 1 epoch,(919m 29s) is 0.506791
# Loss at 14700 paragraphs, 1 epoch,(922m 39s) is -0.506559
# Accuracy at 14700 paragraphs, 1 epoch,(922m 40s) is 0.506564
# Loss at 14750 paragraphs, 1 epoch,(925m 49s) is -0.506605
# Accuracy at 14750 paragraphs, 1 epoch,(925m 49s) is 0.506610
# Loss at 14800 paragraphs, 1 epoch,(928m 59s) is -0.506718
# Accuracy at 14800 paragraphs, 1 epoch,(928m 59s) is 0.506723
# Loss at 14850 paragraphs, 1 epoch,(932m 9s) is -0.506493
# Accuracy at 14850 paragraphs, 1 epoch,(932m 9s) is 0.506498
# Loss at 14900 paragraphs, 1 epoch,(935m 19s) is -0.506404
# Accuracy at 14900 paragraphs, 1 epoch,(935m 19s) is 0.506409
# Loss at 14950 paragraphs, 1 epoch,(938m 29s) is -0.506517
# Accuracy at 14950 paragraphs, 1 epoch,(938m 29s) is 0.506521
# Loss at 15000 paragraphs, 1 epoch,(941m 40s) is -0.506628
# Accuracy at 15000 paragraphs, 1 epoch,(941m 40s) is 0.506633
# Loss at 15050 paragraphs, 1 epoch,(944m 50s) is -0.506673
# Accuracy at 15050 paragraphs, 1 epoch,(944m 50s) is 0.506677
# Loss at 15100 paragraphs, 1 epoch,(948m 1s) is -0.506584
# Accuracy at 15100 paragraphs, 1 epoch,(948m 1s) is 0.506589
# Loss at 15150 paragraphs, 1 epoch,(951m 11s) is -0.506760
# Accuracy at 15150 paragraphs, 1 epoch,(951m 11s) is 0.506765
# Loss at 15200 paragraphs, 1 epoch,(954m 21s) is -0.506672
# Accuracy at 15200 paragraphs, 1 epoch,(954m 21s) is 0.506677
# Loss at 15250 paragraphs, 1 epoch,(957m 31s) is -0.506388
# Accuracy at 15250 paragraphs, 1 epoch,(957m 31s) is 0.506393
# Loss at 15300 paragraphs, 1 epoch,(960m 40s) is -0.506041
# Accuracy at 15300 paragraphs, 1 epoch,(960m 40s) is 0.506045
# Loss at 15350 paragraphs, 1 epoch,(963m 50s) is -0.506151
# Accuracy at 15350 paragraphs, 1 epoch,(963m 50s) is 0.506156
# Loss at 15400 paragraphs, 1 epoch,(966m 59s) is -0.506391
# Accuracy at 15400 paragraphs, 1 epoch,(966m 59s) is 0.506396
# Loss at 15450 paragraphs, 1 epoch,(970m 8s) is -0.506370
# Accuracy at 15450 paragraphs, 1 epoch,(970m 8s) is 0.506375
# Loss at 15500 paragraphs, 1 epoch,(973m 17s) is -0.506479
# Accuracy at 15500 paragraphs, 1 epoch,(973m 17s) is 0.506483
# Loss at 15550 paragraphs, 1 epoch,(976m 26s) is -0.506394
# Accuracy at 15550 paragraphs, 1 epoch,(976m 26s) is 0.506398
# Loss at 15600 paragraphs, 1 epoch,(979m 34s) is -0.506053
# Accuracy at 15600 paragraphs, 1 epoch,(979m 35s) is 0.506057
# Loss at 15650 paragraphs, 1 epoch,(982m 43s) is -0.505969
# Accuracy at 15650 paragraphs, 1 epoch,(982m 43s) is 0.505974
# Loss at 15700 paragraphs, 1 epoch,(985m 52s) is -0.505314
# Accuracy at 15700 paragraphs, 1 epoch,(985m 52s) is 0.505318
# Loss at 15750 paragraphs, 1 epoch,(989m 1s) is -0.505297
# Accuracy at 15750 paragraphs, 1 epoch,(989m 1s) is 0.505301
# Loss at 15800 paragraphs, 1 epoch,(992m 11s) is -0.504647
# Accuracy at 15800 paragraphs, 1 epoch,(992m 11s) is 0.504652
# Loss at 15850 paragraphs, 1 epoch,(995m 19s) is -0.504569
# Accuracy at 15850 paragraphs, 1 epoch,(995m 19s) is 0.504574
# Loss at 15900 paragraphs, 1 epoch,(998m 27s) is -0.505121
# Accuracy at 15900 paragraphs, 1 epoch,(998m 27s) is 0.505125
# Loss at 15950 paragraphs, 1 epoch,(1001m 35s) is -0.504979
# Accuracy at 15950 paragraphs, 1 epoch,(1001m 36s) is 0.504984
# Loss at 16000 paragraphs, 1 epoch,(1004m 44s) is -0.504964
# Accuracy at 16000 paragraphs, 1 epoch,(1004m 44s) is 0.504968
# Loss at 16050 paragraphs, 1 epoch,(1007m 52s) is -0.505011
# Accuracy at 16050 paragraphs, 1 epoch,(1007m 52s) is 0.505015
# Loss at 16100 paragraphs, 1 epoch,(1011m 1s) is -0.505244
# Accuracy at 16100 paragraphs, 1 epoch,(1011m 1s) is 0.505248
# Loss at 16150 paragraphs, 1 epoch,(1014m 10s) is -0.504918
# Accuracy at 16150 paragraphs, 1 epoch,(1014m 10s) is 0.504922
# Loss at 16200 paragraphs, 1 epoch,(1017m 19s) is -0.504779
# Accuracy at 16200 paragraphs, 1 epoch,(1017m 19s) is 0.504784
# Loss at 16250 paragraphs, 1 epoch,(1020m 27s) is -0.504826
# Accuracy at 16250 paragraphs, 1 epoch,(1020m 27s) is 0.504830
# Loss at 16300 paragraphs, 1 epoch,(1023m 36s) is -0.504873
# Accuracy at 16300 paragraphs, 1 epoch,(1023m 36s) is 0.504877
# Loss at 16350 paragraphs, 1 epoch,(1026m 44s) is -0.504735
# Accuracy at 16350 paragraphs, 1 epoch,(1026m 44s) is 0.504740
# Loss at 16400 paragraphs, 1 epoch,(1029m 52s) is -0.504721
# Accuracy at 16400 paragraphs, 1 epoch,(1029m 52s) is 0.504725
# Loss at 16450 paragraphs, 1 epoch,(1033m 1s) is -0.504524
# Accuracy at 16450 paragraphs, 1 epoch,(1033m 1s) is 0.504529
# Loss at 16500 paragraphs, 1 epoch,(1036m 10s) is -0.504632
# Accuracy at 16500 paragraphs, 1 epoch,(1036m 10s) is 0.504636
# Loss at 16550 paragraphs, 1 epoch,(1039m 19s) is -0.504618
# Accuracy at 16550 paragraphs, 1 epoch,(1039m 19s) is 0.504622
# Loss at 16600 paragraphs, 1 epoch,(1042m 28s) is -0.504423
# Accuracy at 16600 paragraphs, 1 epoch,(1042m 28s) is 0.504427
# Loss at 16650 paragraphs, 1 epoch,(1045m 36s) is -0.503929
# Accuracy at 16650 paragraphs, 1 epoch,(1045m 37s) is 0.503934
# Loss at 16700 paragraphs, 1 epoch,(1048m 45s) is -0.503439
# Accuracy at 16700 paragraphs, 1 epoch,(1048m 45s) is 0.503443
# Loss at 16750 paragraphs, 1 epoch,(1051m 53s) is -0.503369
# Accuracy at 16750 paragraphs, 1 epoch,(1051m 54s) is 0.503373
# Loss at 16800 paragraphs, 1 epoch,(1055m 2s) is -0.503478
# Accuracy at 16800 paragraphs, 1 epoch,(1055m 2s) is 0.503482
# Loss at 16850 paragraphs, 1 epoch,(1058m 12s) is -0.503527
# Accuracy at 16850 paragraphs, 1 epoch,(1058m 12s) is 0.503531
# Loss at 16900 paragraphs, 1 epoch,(1061m 21s) is -0.503694
# Accuracy at 16900 paragraphs, 1 epoch,(1061m 21s) is 0.503698
# Loss at 16950 paragraphs, 1 epoch,(1064m 30s) is -0.503565
# Accuracy at 16950 paragraphs, 1 epoch,(1064m 30s) is 0.503569
# Loss at 17000 paragraphs, 1 epoch,(1067m 39s) is -0.503613
# Accuracy at 17000 paragraphs, 1 epoch,(1067m 39s) is 0.503617
# Loss at 17050 paragraphs, 1 epoch,(1070m 49s) is -0.503075
# Accuracy at 17050 paragraphs, 1 epoch,(1070m 49s) is 0.503079
# Loss at 17100 paragraphs, 1 epoch,(1073m 59s) is -0.502832
# Accuracy at 17100 paragraphs, 1 epoch,(1073m 59s) is 0.502836
# Loss at 17150 paragraphs, 1 epoch,(1077m 8s) is -0.502824
# Accuracy at 17150 paragraphs, 1 epoch,(1077m 8s) is 0.502828
# Loss at 17200 paragraphs, 1 epoch,(1080m 17s) is -0.502990
# Accuracy at 17200 paragraphs, 1 epoch,(1080m 17s) is 0.502994
# Loss at 17250 paragraphs, 1 epoch,(1083m 26s) is -0.502981
# Accuracy at 17250 paragraphs, 1 epoch,(1083m 26s) is 0.502985
# Loss at 17300 paragraphs, 1 epoch,(1086m 34s) is -0.502915
# Accuracy at 17300 paragraphs, 1 epoch,(1086m 35s) is 0.502919
# Loss at 17350 paragraphs, 1 epoch,(1089m 43s) is -0.502906
# Accuracy at 17350 paragraphs, 1 epoch,(1089m 43s) is 0.502910
# Loss at 17400 paragraphs, 1 epoch,(1092m 52s) is -0.503070
# Accuracy at 17400 paragraphs, 1 epoch,(1092m 52s) is 0.503075
# Loss at 17450 paragraphs, 1 epoch,(1096m 1s) is -0.503520
# Accuracy at 17450 paragraphs, 1 epoch,(1096m 1s) is 0.503524
# Loss at 17500 paragraphs, 1 epoch,(1099m 10s) is -0.503167
# Accuracy at 17500 paragraphs, 1 epoch,(1099m 10s) is 0.503171
# Loss at 17550 paragraphs, 1 epoch,(1102m 19s) is -0.502987
# Accuracy at 17550 paragraphs, 1 epoch,(1102m 19s) is 0.502991
# Loss at 17600 paragraphs, 1 epoch,(1105m 27s) is -0.503149
# Accuracy at 17600 paragraphs, 1 epoch,(1105m 27s) is 0.503153
# Loss at 17650 paragraphs, 1 epoch,(1108m 36s) is -0.503084
# Accuracy at 17650 paragraphs, 1 epoch,(1108m 36s) is 0.503088
# Loss at 17700 paragraphs, 1 epoch,(1111m 46s) is -0.502962
# Accuracy at 17700 paragraphs, 1 epoch,(1111m 46s) is 0.502966
# Loss at 17750 paragraphs, 1 epoch,(1114m 54s) is -0.502897
# Accuracy at 17750 paragraphs, 1 epoch,(1114m 54s) is 0.502901
# Loss at 17800 paragraphs, 1 epoch,(1118m 3s) is -0.502945
# Accuracy at 17800 paragraphs, 1 epoch,(1118m 3s) is 0.502949
# Loss at 17850 paragraphs, 1 epoch,(1121m 12s) is -0.502881
# Accuracy at 17850 paragraphs, 1 epoch,(1121m 12s) is 0.502885
# Loss at 17900 paragraphs, 1 epoch,(1124m 21s) is -0.502985
# Accuracy at 17900 paragraphs, 1 epoch,(1124m 21s) is 0.502989
# Loss at 17950 paragraphs, 1 epoch,(1127m 31s) is -0.503032
# Accuracy at 17950 paragraphs, 1 epoch,(1127m 31s) is 0.503036
# Loss at 18000 paragraphs, 1 epoch,(1130m 40s) is -0.503190
# Accuracy at 18000 paragraphs, 1 epoch,(1130m 40s) is 0.503194
# Loss at 18050 paragraphs, 1 epoch,(1133m 49s) is -0.503348
# Accuracy at 18050 paragraphs, 1 epoch,(1133m 49s) is 0.503352
# Loss at 18100 paragraphs, 1 epoch,(1136m 58s) is -0.503117
# Accuracy at 18100 paragraphs, 1 epoch,(1136m 58s) is 0.503121
# Loss at 18150 paragraphs, 1 epoch,(1140m 7s) is -0.503384
# Accuracy at 18150 paragraphs, 1 epoch,(1140m 8s) is 0.503388
# Loss at 18200 paragraphs, 1 epoch,(1143m 16s) is -0.503760
# Accuracy at 18200 paragraphs, 1 epoch,(1143m 16s) is 0.503764
# Loss at 18250 paragraphs, 1 epoch,(1146m 25s) is -0.503640
# Accuracy at 18250 paragraphs, 1 epoch,(1146m 25s) is 0.503644
# Loss at 18300 paragraphs, 1 epoch,(1149m 34s) is -0.503466
# Accuracy at 18300 paragraphs, 1 epoch,(1149m 34s) is 0.503470
# Loss at 18350 paragraphs, 1 epoch,(1152m 43s) is -0.503456
# Accuracy at 18350 paragraphs, 1 epoch,(1152m 43s) is 0.503460
# Loss at 18400 paragraphs, 1 epoch,(1155m 52s) is -0.503338
# Accuracy at 18400 paragraphs, 1 epoch,(1155m 52s) is 0.503342
# Loss at 18450 paragraphs, 1 epoch,(1159m 0s) is -0.503329
# Accuracy at 18450 paragraphs, 1 epoch,(1159m 0s) is 0.503333
# Loss at 18500 paragraphs, 1 epoch,(1162m 9s) is -0.503158
# Accuracy at 18500 paragraphs, 1 epoch,(1162m 9s) is 0.503162
# Loss at 18550 paragraphs, 1 epoch,(1165m 17s) is -0.502772
# Accuracy at 18550 paragraphs, 1 epoch,(1165m 17s) is 0.502776
# Loss at 18600 paragraphs, 1 epoch,(1168m 26s) is -0.502926
# Accuracy at 18600 paragraphs, 1 epoch,(1168m 26s) is 0.502930
# Loss at 18650 paragraphs, 1 epoch,(1171m 35s) is -0.502543
# Accuracy at 18650 paragraphs, 1 epoch,(1171m 35s) is 0.502547
# Loss at 18700 paragraphs, 1 epoch,(1174m 44s) is -0.502536
# Accuracy at 18700 paragraphs, 1 epoch,(1174m 44s) is 0.502540
# Loss at 18750 paragraphs, 1 epoch,(1177m 53s) is -0.502476
# Accuracy at 18750 paragraphs, 1 epoch,(1177m 53s) is 0.502480
# Loss at 18800 paragraphs, 1 epoch,(1181m 1s) is -0.502257
# Accuracy at 18800 paragraphs, 1 epoch,(1181m 2s) is 0.502261
# Loss at 18850 paragraphs, 1 epoch,(1184m 11s) is -0.502569
# Accuracy at 18850 paragraphs, 1 epoch,(1184m 11s) is 0.502573
# Loss at 18900 paragraphs, 1 epoch,(1187m 20s) is -0.502298
# Accuracy at 18900 paragraphs, 1 epoch,(1187m 20s) is 0.502301
# Loss at 18950 paragraphs, 1 epoch,(1190m 30s) is -0.502081
# Accuracy at 18950 paragraphs, 1 epoch,(1190m 30s) is 0.502084
# Loss at 19000 paragraphs, 1 epoch,(1193m 39s) is -0.502233
# Accuracy at 19000 paragraphs, 1 epoch,(1193m 39s) is 0.502237
# Loss at 19050 paragraphs, 1 epoch,(1196m 49s) is -0.502017
# Accuracy at 19050 paragraphs, 1 epoch,(1196m 49s) is 0.502021
# Loss at 19100 paragraphs, 1 epoch,(1199m 58s) is -0.502012
# Accuracy at 19100 paragraphs, 1 epoch,(1199m 58s) is 0.502016
# Loss at 19150 paragraphs, 1 epoch,(1203m 7s) is -0.502163
# Accuracy at 19150 paragraphs, 1 epoch,(1203m 8s) is 0.502167
# Loss at 19200 paragraphs, 1 epoch,(1206m 16s) is -0.502210
# Accuracy at 19200 paragraphs, 1 epoch,(1206m 17s) is 0.502213
# Loss at 19250 paragraphs, 1 epoch,(1209m 26s) is -0.502204
# Accuracy at 19250 paragraphs, 1 epoch,(1209m 26s) is 0.502208
# Loss at 19300 paragraphs, 1 epoch,(1212m 35s) is -0.502043
# Accuracy at 19300 paragraphs, 1 epoch,(1212m 35s) is 0.502047
# Loss at 19350 paragraphs, 1 epoch,(1215m 44s) is -0.502038
# Accuracy at 19350 paragraphs, 1 epoch,(1215m 44s) is 0.502041
# Loss at 19400 paragraphs, 1 epoch,(1218m 53s) is -0.501878
# Accuracy at 19400 paragraphs, 1 epoch,(1218m 53s) is 0.501881
# Loss at 19450 paragraphs, 1 epoch,(1222m 3s) is -0.502027
# Accuracy at 19450 paragraphs, 1 epoch,(1222m 3s) is 0.502031
# Loss at 19500 paragraphs, 1 epoch,(1225m 12s) is -0.502381
# Accuracy at 19500 paragraphs, 1 epoch,(1225m 12s) is 0.502384
# Loss at 19550 paragraphs, 1 epoch,(1228m 21s) is -0.502170
# Accuracy at 19550 paragraphs, 1 epoch,(1228m 21s) is 0.502174
# Loss at 19600 paragraphs, 1 epoch,(1231m 29s) is -0.501961
# Accuracy at 19600 paragraphs, 1 epoch,(1231m 30s) is 0.501964
# Loss at 19650 paragraphs, 1 epoch,(1234m 39s) is -0.501650
# Accuracy at 19650 paragraphs, 1 epoch,(1234m 39s) is 0.501654
# Loss at 19700 paragraphs, 1 epoch,(1237m 48s) is -0.501595
# Accuracy at 19700 paragraphs, 1 epoch,(1237m 48s) is 0.501599
# Loss at 19750 paragraphs, 1 epoch,(1240m 57s) is -0.501490
# Accuracy at 19750 paragraphs, 1 epoch,(1240m 57s) is 0.501494
# Loss at 19800 paragraphs, 1 epoch,(1244m 7s) is -0.501638
# Accuracy at 19800 paragraphs, 1 epoch,(1244m 7s) is 0.501641
# Loss at 19850 paragraphs, 1 epoch,(1247m 16s) is -0.501785
# Accuracy at 19850 paragraphs, 1 epoch,(1247m 16s) is 0.501788
# Loss at 19900 paragraphs, 1 epoch,(1250m 25s) is -0.501579
# Accuracy at 19900 paragraphs, 1 epoch,(1250m 25s) is 0.501583
# Loss at 19950 paragraphs, 1 epoch,(1253m 33s) is -0.502026
# Accuracy at 19950 paragraphs, 1 epoch,(1253m 34s) is 0.502030
# Loss at 20000 paragraphs, 1 epoch,(1256m 42s) is -0.502071
# Accuracy at 20000 paragraphs, 1 epoch,(1256m 43s) is 0.502075
# Loss at 20050 paragraphs, 1 epoch,(1259m 52s) is -0.502016
# Accuracy at 20050 paragraphs, 1 epoch,(1259m 52s) is 0.502020
# Loss at 20100 paragraphs, 1 epoch,(1263m 1s) is -0.501961
# Accuracy at 20100 paragraphs, 1 epoch,(1263m 1s) is 0.501965
# Loss at 20150 paragraphs, 1 epoch,(1266m 10s) is -0.501907
# Accuracy at 20150 paragraphs, 1 epoch,(1266m 10s) is 0.501911
# Loss at 20200 paragraphs, 1 epoch,(1269m 20s) is -0.501853
# Accuracy at 20200 paragraphs, 1 epoch,(1269m 20s) is 0.501856
# Loss at 20250 paragraphs, 1 epoch,(1272m 29s) is -0.501749
# ...
# Accuracy at 16150 paragraphs, 2 epoch,(2617m 54s) is 0.502074
# Loss at 16200 paragraphs, 2 epoch,(2621m 11s) is -0.501883
# Accuracy at 16200 paragraphs, 2 epoch,(2621m 11s) is 0.501883
# Loss at 16250 paragraphs, 2 epoch,(2624m 27s) is -0.501815
# Accuracy at 16250 paragraphs, 2 epoch,(2624m 27s) is 0.501815
# Loss at 16300 paragraphs, 2 epoch,(2627m 42s) is -0.501748
# Accuracy at 16300 paragraphs, 2 epoch,(2627m 43s) is 0.501748
# Loss at 16350 paragraphs, 2 epoch,(2630m 59s) is -0.501682
# Accuracy at 16350 paragraphs, 2 epoch,(2630m 59s) is 0.501682
# Loss at 16400 paragraphs, 2 epoch,(2634m 15s) is -0.501372
# Accuracy at 16400 paragraphs, 2 epoch,(2634m 15s) is 0.501372
# Loss at 16450 paragraphs, 2 epoch,(2637m 30s) is -0.501185
# Accuracy at 16450 paragraphs, 2 epoch,(2637m 31s) is 0.501185
# Loss at 16500 paragraphs, 2 epoch,(2640m 46s) is -0.501121
# Accuracy at 16500 paragraphs, 2 epoch,(2640m 46s) is 0.501121
# Loss at 16550 paragraphs, 2 epoch,(2644m 1s) is -0.501118
# Accuracy at 16550 paragraphs, 2 epoch,(2644m 1s) is 0.501118
# Loss at 16600 paragraphs, 2 epoch,(2647m 16s) is -0.500994
# Accuracy at 16600 paragraphs, 2 epoch,(2647m 17s) is 0.500994
# Loss at 16650 paragraphs, 2 epoch,(2650m 32s) is -0.500991
# Accuracy at 16650 paragraphs, 2 epoch,(2650m 32s) is 0.500991
# Loss at 16700 paragraphs, 2 epoch,(2653m 46s) is -0.500928
# Accuracy at 16700 paragraphs, 2 epoch,(2653m 46s) is 0.500928
# Loss at 16750 paragraphs, 2 epoch,(2657m 0s) is -0.500985
# Accuracy at 16750 paragraphs, 2 epoch,(2657m 0s) is 0.500985
# Loss at 16800 paragraphs, 2 epoch,(2660m 14s) is -0.501339
# Accuracy at 16800 paragraphs, 2 epoch,(2660m 14s) is 0.501339
# Loss at 16850 paragraphs, 2 epoch,(2663m 27s) is -0.501454
# Accuracy at 16850 paragraphs, 2 epoch,(2663m 27s) is 0.501454
# Loss at 16900 paragraphs, 2 epoch,(2666m 39s) is -0.501745
# Accuracy at 16900 paragraphs, 2 epoch,(2666m 40s) is 0.501745
# Loss at 16950 paragraphs, 2 epoch,(2669m 52s) is -0.502094
# Accuracy at 16950 paragraphs, 2 epoch,(2669m 52s) is 0.502094
# Loss at 17000 paragraphs, 2 epoch,(2673m 5s) is -0.502206
# Accuracy at 17000 paragraphs, 2 epoch,(2673m 5s) is 0.502206
# Loss at 17050 paragraphs, 2 epoch,(2676m 19s) is -0.502317
# Accuracy at 17050 paragraphs, 2 epoch,(2676m 19s) is 0.502317
# Loss at 17100 paragraphs, 2 epoch,(2679m 33s) is -0.502427
# Accuracy at 17100 paragraphs, 2 epoch,(2679m 33s) is 0.502427
# Loss at 17150 paragraphs, 2 epoch,(2682m 46s) is -0.502070
# Accuracy at 17150 paragraphs, 2 epoch,(2682m 46s) is 0.502070
# Loss at 17200 paragraphs, 2 epoch,(2685m 58s) is -0.502122
# Accuracy at 17200 paragraphs, 2 epoch,(2685m 58s) is 0.502122
# Loss at 17250 paragraphs, 2 epoch,(2689m 10s) is -0.502116
# Accuracy at 17250 paragraphs, 2 epoch,(2689m 10s) is 0.502116
# Loss at 17300 paragraphs, 2 epoch,(2692m 23s) is -0.502225
# Accuracy at 17300 paragraphs, 2 epoch,(2692m 23s) is 0.502225
# Loss at 17350 paragraphs, 2 epoch,(2695m 36s) is -0.502219
# Accuracy at 17350 paragraphs, 2 epoch,(2695m 36s) is 0.502219
# Loss at 17400 paragraphs, 2 epoch,(2698m 49s) is -0.502385
# Accuracy at 17400 paragraphs, 2 epoch,(2698m 49s) is 0.502385
# Loss at 17450 paragraphs, 2 epoch,(2702m 2s) is -0.502493
# Accuracy at 17450 paragraphs, 2 epoch,(2702m 2s) is 0.502493
# Loss at 17500 paragraphs, 2 epoch,(2705m 14s) is -0.502886
# Accuracy at 17500 paragraphs, 2 epoch,(2705m 14s) is 0.502886
# Loss at 17550 paragraphs, 2 epoch,(2708m 27s) is -0.502649
# Accuracy at 17550 paragraphs, 2 epoch,(2708m 27s) is 0.502649
# Loss at 17600 paragraphs, 2 epoch,(2711m 39s) is -0.502131
# Accuracy at 17600 paragraphs, 2 epoch,(2711m 39s) is 0.502131
# Loss at 17650 paragraphs, 2 epoch,(2714m 52s) is -0.502238
# Accuracy at 17650 paragraphs, 2 epoch,(2714m 52s) is 0.502238
# Loss at 17700 paragraphs, 2 epoch,(2718m 4s) is -0.502288
# Accuracy at 17700 paragraphs, 2 epoch,(2718m 5s) is 0.502288
# Loss at 17750 paragraphs, 2 epoch,(2721m 17s) is -0.502282
# Accuracy at 17750 paragraphs, 2 epoch,(2721m 17s) is 0.502282
# Loss at 17800 paragraphs, 2 epoch,(2724m 29s) is -0.502388
# Accuracy at 17800 paragraphs, 2 epoch,(2724m 30s) is 0.502388
# Loss at 17850 paragraphs, 2 epoch,(2727m 42s) is -0.502549
# Accuracy at 17850 paragraphs, 2 epoch,(2727m 42s) is 0.502549
# Loss at 17900 paragraphs, 2 epoch,(2730m 55s) is -0.502207
# Accuracy at 17900 paragraphs, 2 epoch,(2730m 55s) is 0.502207
# Loss at 17950 paragraphs, 2 epoch,(2734m 7s) is -0.502200
# Accuracy at 17950 paragraphs, 2 epoch,(2734m 7s) is 0.502200
# Loss at 18000 paragraphs, 2 epoch,(2737m 20s) is -0.502139
# Accuracy at 18000 paragraphs, 2 epoch,(2737m 20s) is 0.502139
# Loss at 18050 paragraphs, 2 epoch,(2740m 33s) is -0.502244
# Accuracy at 18050 paragraphs, 2 epoch,(2740m 33s) is 0.502244
# Loss at 18100 paragraphs, 2 epoch,(2743m 46s) is -0.502624
# Accuracy at 18100 paragraphs, 2 epoch,(2743m 46s) is 0.502624
# Loss at 18150 paragraphs, 2 epoch,(2746m 59s) is -0.502837
# Accuracy at 18150 paragraphs, 2 epoch,(2746m 59s) is 0.502837
# Loss at 18200 paragraphs, 2 epoch,(2750m 12s) is -0.502939
# Accuracy at 18200 paragraphs, 2 epoch,(2750m 12s) is 0.502939
# Loss at 18250 paragraphs, 2 epoch,(2753m 25s) is -0.503260
# Accuracy at 18250 paragraphs, 2 epoch,(2753m 25s) is 0.503260
# Loss at 18300 paragraphs, 2 epoch,(2756m 39s) is -0.503197
# Accuracy at 18300 paragraphs, 2 epoch,(2756m 39s) is 0.503197
# Loss at 18350 paragraphs, 2 epoch,(2759m 52s) is -0.503297
# Accuracy at 18350 paragraphs, 2 epoch,(2759m 52s) is 0.503297
# Loss at 18400 paragraphs, 2 epoch,(2763m 5s) is -0.503288
# Accuracy at 18400 paragraphs, 2 epoch,(2763m 5s) is 0.503288
# Loss at 18450 paragraphs, 2 epoch,(2766m 18s) is -0.503171
# Accuracy at 18450 paragraphs, 2 epoch,(2766m 18s) is 0.503171
# Loss at 18500 paragraphs, 2 epoch,(2769m 31s) is -0.503162
# Accuracy at 18500 paragraphs, 2 epoch,(2769m 31s) is 0.503162
# Loss at 18550 paragraphs, 2 epoch,(2772m 43s) is -0.502992
# Accuracy at 18550 paragraphs, 2 epoch,(2772m 43s) is 0.502992
# Loss at 18600 paragraphs, 2 epoch,(2775m 56s) is -0.503145
# Accuracy at 18600 paragraphs, 2 epoch,(2775m 56s) is 0.503145
# Loss at 18650 paragraphs, 2 epoch,(2779m 9s) is -0.503029
# Accuracy at 18650 paragraphs, 2 epoch,(2779m 9s) is 0.503029
# Loss at 18700 paragraphs, 2 epoch,(2782m 22s) is -0.503021
# Accuracy at 18700 paragraphs, 2 epoch,(2782m 22s) is 0.503021
# Loss at 18750 paragraphs, 2 epoch,(2785m 35s) is -0.502853
# Accuracy at 18750 paragraphs, 2 epoch,(2785m 35s) is 0.502853
# Loss at 18800 paragraphs, 2 epoch,(2788m 48s) is -0.503271
# Accuracy at 18800 paragraphs, 2 epoch,(2788m 48s) is 0.503271
# Loss at 18850 paragraphs, 2 epoch,(2792m 1s) is -0.503368
# Accuracy at 18850 paragraphs, 2 epoch,(2792m 1s) is 0.503369
# Loss at 18900 paragraphs, 2 epoch,(2795m 14s) is -0.503360
# Accuracy at 18900 paragraphs, 2 epoch,(2795m 14s) is 0.503360
# Loss at 18950 paragraphs, 2 epoch,(2798m 27s) is -0.503562
# Accuracy at 18950 paragraphs, 2 epoch,(2798m 27s) is 0.503562
# Loss at 19000 paragraphs, 2 epoch,(2801m 39s) is -0.503605
# Accuracy at 19000 paragraphs, 2 epoch,(2801m 39s) is 0.503605
# Loss at 19050 paragraphs, 2 epoch,(2804m 52s) is -0.503281
# Accuracy at 19050 paragraphs, 2 epoch,(2804m 52s) is 0.503281
# Loss at 19100 paragraphs, 2 epoch,(2808m 5s) is -0.503063
# Accuracy at 19100 paragraphs, 2 epoch,(2808m 5s) is 0.503063
# Loss at 19150 paragraphs, 2 epoch,(2811m 18s) is -0.502637
# Accuracy at 19150 paragraphs, 2 epoch,(2811m 19s) is 0.502637
# Loss at 19200 paragraphs, 2 epoch,(2814m 31s) is -0.502318
# Accuracy at 19200 paragraphs, 2 epoch,(2814m 32s) is 0.502318
# Loss at 19250 paragraphs, 2 epoch,(2817m 44s) is -0.502364
# Accuracy at 19250 paragraphs, 2 epoch,(2817m 44s) is 0.502364
# Loss at 19300 paragraphs, 2 epoch,(2820m 56s) is -0.502254
# Accuracy at 19300 paragraphs, 2 epoch,(2820m 57s) is 0.502254
# Loss at 19350 paragraphs, 2 epoch,(2824m 9s) is -0.502300
# Accuracy at 19350 paragraphs, 2 epoch,(2824m 9s) is 0.502300
# Loss at 19400 paragraphs, 2 epoch,(2827m 22s) is -0.502654
# Accuracy at 19400 paragraphs, 2 epoch,(2827m 22s) is 0.502655
# Loss at 19450 paragraphs, 2 epoch,(2830m 35s) is -0.502648
# Accuracy at 19450 paragraphs, 2 epoch,(2830m 35s) is 0.502648
# Loss at 19500 paragraphs, 2 epoch,(2833m 47s) is -0.502949
# Accuracy at 19500 paragraphs, 2 epoch,(2833m 48s) is 0.502949
# Loss at 19550 paragraphs, 2 epoch,(2837m 0s) is -0.502941
# Accuracy at 19550 paragraphs, 2 epoch,(2837m 1s) is 0.502941
# Loss at 19600 paragraphs, 2 epoch,(2840m 14s) is -0.502729
# Accuracy at 19600 paragraphs, 2 epoch,(2840m 14s) is 0.502729
# Loss at 19650 paragraphs, 2 epoch,(2843m 26s) is -0.502824
# Accuracy at 19650 paragraphs, 2 epoch,(2843m 26s) is 0.502824
# Loss at 19700 paragraphs, 2 epoch,(2846m 39s) is -0.502919
# Accuracy at 19700 paragraphs, 2 epoch,(2846m 39s) is 0.502919
# Loss at 19750 paragraphs, 2 epoch,(2849m 51s) is -0.502759
# Accuracy at 19750 paragraphs, 2 epoch,(2849m 52s) is 0.502759
# Loss at 19800 paragraphs, 2 epoch,(2853m 4s) is -0.502651
# Accuracy at 19800 paragraphs, 2 epoch,(2853m 4s) is 0.502651
# Loss at 19850 paragraphs, 2 epoch,(2856m 18s) is -0.502494
# Accuracy at 19850 paragraphs, 2 epoch,(2856m 18s) is 0.502494
# Loss at 19900 paragraphs, 2 epoch,(2859m 30s) is -0.502387
# Accuracy at 19900 paragraphs, 2 epoch,(2859m 30s) is 0.502387
# Loss at 19950 paragraphs, 2 epoch,(2862m 43s) is -0.502331
# Accuracy at 19950 paragraphs, 2 epoch,(2862m 43s) is 0.502331
# Loss at 20000 paragraphs, 2 epoch,(2865m 55s) is -0.502225
# Accuracy at 20000 paragraphs, 2 epoch,(2865m 55s) is 0.502225
# Loss at 20050 paragraphs, 2 epoch,(2869m 8s) is -0.502269
# Accuracy at 20050 paragraphs, 2 epoch,(2869m 8s) is 0.502269
# Loss at 20100 paragraphs, 2 epoch,(2872m 21s) is -0.502164
# Accuracy at 20100 paragraphs, 2 epoch,(2872m 21s) is 0.502164
# Loss at 20150 paragraphs, 2 epoch,(2875m 34s) is -0.501911
# Accuracy at 20150 paragraphs, 2 epoch,(2875m 34s) is 0.501911
# Loss at 20200 paragraphs, 2 epoch,(2878m 47s) is -0.502153
# Accuracy at 20200 paragraphs, 2 epoch,(2878m 47s) is 0.502153
# Loss at 20250 paragraphs, 2 epoch,(2881m 59s) is -0.502395
# Accuracy at 20250 paragraphs, 2 epoch,(2881m 59s) is 0.502395
# Loss at 20300 paragraphs, 2 epoch,(2885m 12s) is -0.502241
# Accuracy at 20300 paragraphs, 2 epoch,(2885m 12s) is 0.502241
# Loss at 20350 paragraphs, 2 epoch,(2888m 25s) is -0.502187
# Accuracy at 20350 paragraphs, 2 epoch,(2888m 25s) is 0.502187
# Loss at 20400 paragraphs, 2 epoch,(2891m 37s) is -0.501838
# Accuracy at 20400 paragraphs, 2 epoch,(2891m 38s) is 0.501838
# Loss at 20450 paragraphs, 2 epoch,(2894m 50s) is -0.501736
# Accuracy at 20450 paragraphs, 2 epoch,(2894m 51s) is 0.501736
# Loss at 20500 paragraphs, 2 epoch,(2898m 3s) is -0.502073
# Accuracy at 20500 paragraphs, 2 epoch,(2898m 3s) is 0.502073
# Loss at 20550 paragraphs, 2 epoch,(2901m 16s) is -0.501776
# Accuracy at 20550 paragraphs, 2 epoch,(2901m 16s) is 0.501776
# Loss at 20600 paragraphs, 2 epoch,(2904m 29s) is -0.501626
# Accuracy at 20600 paragraphs, 2 epoch,(2904m 29s) is 0.501626
# Loss at 20650 paragraphs, 2 epoch,(2907m 42s) is -0.501816
# Accuracy at 20650 paragraphs, 2 epoch,(2907m 43s) is 0.501816
# Loss at 20700 paragraphs, 2 epoch,(2910m 55s) is -0.501763
# Accuracy at 20700 paragraphs, 2 epoch,(2910m 55s) is 0.501763
# Loss at 20750 paragraphs, 2 epoch,(2914m 7s) is -0.501663
# Accuracy at 20750 paragraphs, 2 epoch,(2914m 7s) is 0.501663
# Loss at 20800 paragraphs, 2 epoch,(2917m 19s) is -0.501514
# Accuracy at 20800 paragraphs, 2 epoch,(2917m 20s) is 0.501514
# Loss at 20850 paragraphs, 2 epoch,(2920m 32s) is -0.501367
# Accuracy at 20850 paragraphs, 2 epoch,(2920m 33s) is 0.501367
# Loss at 20900 paragraphs, 2 epoch,(2923m 46s) is -0.501268
# Accuracy at 20900 paragraphs, 2 epoch,(2923m 46s) is 0.501268
# Loss at 20950 paragraphs, 2 epoch,(2926m 59s) is -0.501265
# Accuracy at 20950 paragraphs, 2 epoch,(2926m 59s) is 0.501265
# Loss at 21000 paragraphs, 2 epoch,(2930m 12s) is -0.501262
# Accuracy at 21000 paragraphs, 2 epoch,(2930m 12s) is 0.501262
# Loss at 21050 paragraphs, 2 epoch,(2933m 25s) is -0.501021
# Accuracy at 21050 paragraphs, 2 epoch,(2933m 25s) is 0.501021
# Loss at 21100 paragraphs, 2 epoch,(2936m 37s) is -0.501019
# Accuracy at 21100 paragraphs, 2 epoch,(2936m 38s) is 0.501019
# Loss at 21150 paragraphs, 2 epoch,(2939m 51s) is -0.500969
# Accuracy at 21150 paragraphs, 2 epoch,(2939m 51s) is 0.500969
# Loss at 21200 paragraphs, 2 epoch,(2943m 4s) is -0.501250
# Accuracy at 21200 paragraphs, 2 epoch,(2943m 4s) is 0.501250
# Loss at 21250 paragraphs, 2 epoch,(2946m 17s) is -0.501059
# Accuracy at 21250 paragraphs, 2 epoch,(2946m 17s) is 0.501059
# Loss at 21300 paragraphs, 2 epoch,(2949m 32s) is -0.500868
# Accuracy at 21300 paragraphs, 2 epoch,(2949m 32s) is 0.500869
# Loss at 21350 paragraphs, 2 epoch,(2952m 47s) is -0.500773
# Accuracy at 21350 paragraphs, 2 epoch,(2952m 47s) is 0.500773
# Loss at 21400 paragraphs, 2 epoch,(2956m 3s) is -0.500678
# Accuracy at 21400 paragraphs, 2 epoch,(2956m 3s) is 0.500678
# Loss at 21450 paragraphs, 2 epoch,(2959m 18s) is -0.500443
# Accuracy at 21450 paragraphs, 2 epoch,(2959m 18s) is 0.500443
# Loss at 21500 paragraphs, 2 epoch,(2962m 33s) is -0.500302
# Accuracy at 21500 paragraphs, 2 epoch,(2962m 34s) is 0.500302
# Loss at 21550 paragraphs, 2 epoch,(2965m 48s) is -0.500534
# Accuracy at 21550 paragraphs, 2 epoch,(2965m 48s) is 0.500534
# Loss at 21600 paragraphs, 2 epoch,(2969m 3s) is -0.500486
# Accuracy at 21600 paragraphs, 2 epoch,(2969m 3s) is 0.500486
# Loss at 21650 paragraphs, 2 epoch,(2972m 18s) is -0.500531
# Accuracy at 21650 paragraphs, 2 epoch,(2972m 18s) is 0.500531
# Loss at 21700 paragraphs, 2 epoch,(2975m 33s) is -0.500668
# Accuracy at 21700 paragraphs, 2 epoch,(2975m 33s) is 0.500668
# Loss at 21750 paragraphs, 2 epoch,(2978m 47s) is -0.500713
# Accuracy at 21750 paragraphs, 2 epoch,(2978m 47s) is 0.500713
# Loss at 21800 paragraphs, 2 epoch,(2982m 1s) is -0.500573
# Accuracy at 21800 paragraphs, 2 epoch,(2982m 2s) is 0.500573
# Loss at 21850 paragraphs, 2 epoch,(2985m 16s) is -0.500618
# Accuracy at 21850 paragraphs, 2 epoch,(2985m 16s) is 0.500618
# Loss at 21900 paragraphs, 2 epoch,(2988m 30s) is -0.500708
# Accuracy at 21900 paragraphs, 2 epoch,(2988m 31s) is 0.500708
# Loss at 21950 paragraphs, 2 epoch,(2991m 45s) is -0.500752
# Accuracy at 21950 paragraphs, 2 epoch,(2991m 45s) is 0.500752
# Loss at 22000 paragraphs, 2 epoch,(2994m 59s) is -0.500841
# Accuracy at 22000 paragraphs, 2 epoch,(2995m 0s) is 0.500841
# Loss at 22050 paragraphs, 2 epoch,(2998m 14s) is -0.500975
# Accuracy at 22050 paragraphs, 2 epoch,(2998m 14s) is 0.500975
# Loss at 22100 paragraphs, 2 epoch,(3001m 29s) is -0.500792
# Accuracy at 22100 paragraphs, 2 epoch,(3001m 29s) is 0.500792
# Loss at 22150 paragraphs, 2 epoch,(3004m 44s) is -0.500790
# Accuracy at 22150 paragraphs, 2 epoch,(3004m 44s) is 0.500790
# Loss at 22200 paragraphs, 2 epoch,(3008m 0s) is -0.500923
# Accuracy at 22200 paragraphs, 2 epoch,(3008m 0s) is 0.500923
# Loss at 22250 paragraphs, 2 epoch,(3011m 15s) is -0.500786
# Accuracy at 22250 paragraphs, 2 epoch,(3011m 15s) is 0.500786
# Loss at 22300 paragraphs, 2 epoch,(3014m 29s) is -0.500830
# Accuracy at 22300 paragraphs, 2 epoch,(3014m 30s) is 0.500830
# Loss at 22350 paragraphs, 2 epoch,(3017m 45s) is -0.500872
# Accuracy at 22350 paragraphs, 2 epoch,(3017m 45s) is 0.500872
# Loss at 22400 paragraphs, 2 epoch,(3021m 0s) is -0.501049
# Accuracy at 22400 paragraphs, 2 epoch,(3021m 0s) is 0.501049
# Loss at 22450 paragraphs, 2 epoch,(3024m 15s) is -0.500913
# Accuracy at 22450 paragraphs, 2 epoch,(3024m 16s) is 0.500913
# Loss at 22500 paragraphs, 2 epoch,(3027m 30s) is -0.500867
# Accuracy at 22500 paragraphs, 2 epoch,(3027m 31s) is 0.500867
# Loss at 22550 paragraphs, 2 epoch,(3030m 46s) is -0.500732
# Accuracy at 22550 paragraphs, 2 epoch,(3030m 46s) is 0.500732
# Loss at 22600 paragraphs, 2 epoch,(3034m 0s) is -0.500553
# Accuracy at 22600 paragraphs, 2 epoch,(3034m 0s) is 0.500553
# Loss at 22650 paragraphs, 2 epoch,(3037m 17s) is -0.500728
# Accuracy at 22650 paragraphs, 2 epoch,(3037m 17s) is 0.500728
# Loss at 22700 paragraphs, 2 epoch,(3040m 41s) is -0.500859
# Accuracy at 22700 paragraphs, 2 epoch,(3040m 41s) is 0.500859
# Loss at 22750 paragraphs, 2 epoch,(3044m 10s) is -0.500857
# Accuracy at 22750 paragraphs, 2 epoch,(3044m 10s) is 0.500857
